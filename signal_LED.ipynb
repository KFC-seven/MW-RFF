# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader, Subset
from sklearn.model_selection import KFold, train_test_split
from sklearn.metrics import confusion_matrix
import matplotlib
matplotlib.use('agg')
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
from scipy.io import loadmat
import pywt

# ====================== 配置参数 ======================
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'

# 数据参数
SNR_dB = 20
ADD_NOISE = True
ADD_DOPPLER = True
FS = 20e6
FC = 2.4e9
VELOCITY_KMH = 120

# Wavelet 特征
USE_LOG = True
WAVELET = 'db6'
WAVELET_LEVEL = 6

# 训练参数
BATCH_SIZE = 64
EPOCHS = 200
LR = 1e-3
WEIGHT_DECAY = 1e-4
N_SPLITS = 5
PATIENCE = 10

# 保存路径
SAVE_ROOT = "./training_results"
os.makedirs(SAVE_ROOT, exist_ok=True)

# ====================== 数据读取 ======================
DATA_FOLDER = r"..\los_data"  # Wi-Fi MAT 文件路径
file_list = sorted([f for f in os.listdir(DATA_FOLDER) if f.endswith('.mat')])

X_list, y_list = [], []

for idx, file_name in enumerate(file_list):
    mat = loadmat(os.path.join(DATA_FOLDER, file_name))
    if 'data_Ineed' not in mat:
        print(f"Warning: {file_name} 没有 'data_Ineed' 变量！")
        continue
    data_arr = mat['data_Ineed'].T  # 转置为 [num_samples, length]
    X_list.append(data_arr)
    y_list.append(np.full(data_arr.shape[0], idx, dtype=np.int64))
    print(f"第{idx}个文件 ({file_name}) 的数据 shape (转置后): {data_arr.shape}")

X = np.vstack(X_list)
y = np.concatenate(y_list)
num_classes = len(np.unique(y))
print(f"总数据 shape: {X.shape}, 标签 shape: {y.shape}, 类别数: {num_classes}")

# ====================== 数据处理函数 ======================
def compute_doppler_shift(v_kmh, fc_hz):
    if not v_kmh: return 0
    c = 3e8
    v_mps = v_kmh / 3.6
    return fc_hz * v_mps / c

def add_complex_awgn(signal, snr_db):
    if snr_db is None:
        return signal
    power = np.mean(np.abs(signal)**2)
    noise_power = power / (10**(snr_db/10))
    noise_std = np.sqrt(noise_power/2)
    noise = noise_std * (np.random.randn(*signal.shape) + 1j*np.random.randn(*signal.shape))
    return signal + noise

def apply_doppler_shift(signal, fd_hz, fs_hz):
    if fd_hz is None or fd_hz == 0:
        return signal
    t = np.arange(len(signal)) / fs_hz
    return signal * np.exp(1j * 2 * np.pi * fd_hz * t)

def process_signal_led_rff(sig_complex, use_log=False, wavelet='db6', level=6):
    # --------------------
    # 1. FFT 幅度谱
    # --------------------
    freq_sig = np.fft.fft(sig_complex)
    amp = np.abs(freq_sig)
    # 对称频谱，只取前半段
    amp = amp[:len(amp)//2]

    # --------------------
    # 2. 可选 log
    # --------------------
    if use_log:
        amp = np.log(amp + 1e-8)

    # --------------------
    # 3. 小波分解 + 低频置零 + 重构
    # --------------------
    coeffs = pywt.wavedec(amp, wavelet, level=level)
    coeffs[0] = np.zeros_like(coeffs[0])
    rec = pywt.waverec(coeffs, wavelet)
    rec = rec[:len(amp)]

    # --------------------
    # 4. 归一化
    # --------------------
    mu, sigma = rec.mean(), rec.std()
    if sigma < 1e-8:
        feat = (rec - mu).astype(np.float32)
    else:
        feat = ((rec - mu) / (sigma + 1e-8)).astype(np.float32)
    return feat


def preprocess_iq_dataset_led_rff(data_real, snr_db=SNR_dB, velocity_kmh=VELOCITY_KMH,
                                  fc_hz=FC, fs_hz=FS, use_log=USE_LOG,
                                  wavelet=WAVELET, level=WAVELET_LEVEL,
                                  add_noise=ADD_NOISE, add_doppler=ADD_DOPPLER):
    num_samples, sig_len = data_real.shape
    processed_feats = []
    data_complex = data_real.astype(np.complex64)
    fd_hz = compute_doppler_shift(velocity_kmh, fc_hz) if add_doppler else None

    for i in range(num_samples):
        sig = data_complex[i]
        if add_noise: sig = add_complex_awgn(sig, snr_db)
        if add_doppler: sig = apply_doppler_shift(sig, fd_hz, fs_hz)
        # 调用新的 FFT + 小波处理
        feat = process_signal_led_rff(sig, use_log=use_log, wavelet=wavelet, level=level)
        processed_feats.append(feat)
    processed_feats = np.stack(processed_feats, axis=0)
    return torch.tensor(processed_feats, dtype=torch.float32)[:, None, :]  # [N, 1, length]


# ====================== InceptionTime 模型 ======================
class InceptionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        bottleneck_channels = max(1, out_channels // 4)
        self.bottleneck = nn.Conv1d(in_channels, bottleneck_channels, kernel_size=1, bias=False)
        self.conv1 = nn.Conv1d(bottleneck_channels, out_channels, kernel_size=10, padding=5)
        self.conv2 = nn.Conv1d(bottleneck_channels, out_channels, kernel_size=20, padding=10)
        self.conv3 = nn.Conv1d(bottleneck_channels, out_channels, kernel_size=40, padding=20)
        self.maxpool = nn.MaxPool1d(3, stride=1, padding=1)
        self.convpool = nn.Conv1d(bottleneck_channels, out_channels, kernel_size=1, bias=False)
        self.bn = nn.BatchNorm1d(4*out_channels)
        self.relu = nn.ReLU()
    def forward(self, x):
        x_b = self.bottleneck(x)
        c1 = self.conv1(x_b)
        c2 = self.conv2(x_b)
        c3 = self.conv3(x_b)
        c4 = self.convpool(self.maxpool(x_b))
        min_len = min(c1.shape[-1], c2.shape[-1], c3.shape[-1], c4.shape[-1])
        c1 = c1[..., :min_len]; c2 = c2[..., :min_len]; c3 = c3[..., :min_len]; c4 = c4[..., :min_len]
        out = torch.cat([c1, c2, c3, c4], dim=1)
        return self.relu(self.bn(out))

class InceptionTime(nn.Module):
    def __init__(self, num_classes, in_channels=1, channels=32):
        super().__init__()
        self.b1 = InceptionBlock(in_channels, channels)
        self.b2 = InceptionBlock(4*channels, channels)
        self.b3 = InceptionBlock(4*channels, channels)
        self.gap = nn.AdaptiveAvgPool1d(1)
        self.fc = nn.Linear(4*channels, num_classes)
    def forward(self, x):
        if x.shape[-1] % 2 == 1: x = x[..., :-1]
        x = self.b1(x); x = self.b2(x); x = self.b3(x)
        x = self.gap(x).squeeze(-1)
        return self.fc(x)

# ====================== 工具函数 ======================
def evaluate_model(model, dataloader, device, num_classes):
    model.eval()
    correct, total = 0, 0
    all_labels, all_preds = [], []
    with torch.no_grad():
        for xb, yb in dataloader:
            xb, yb = xb.to(device), yb.to(device)
            out = model(xb)
            _, p = torch.max(out, 1)
            correct += (p == yb).sum().item()
            total += yb.size(0)
            all_labels.extend(yb.cpu().numpy())
            all_preds.extend(p.cpu().numpy())
    acc = 100.0 * correct / total
    cm = confusion_matrix(all_labels, all_preds, labels=list(range(num_classes)))
    return acc, cm

def plot_confusion_matrix(cm, classes, fold, save_folder, dataset_type='Test'):
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{dataset_type} Confusion Matrix Fold{fold}')
    plt.ylabel('True')
    plt.xlabel('Predicted')
    plt.savefig(os.path.join(save_folder, f'{dataset_type.lower()}_cm_fold{fold}.png'))
    plt.close()

def plot_curves(train_losses, val_losses, train_acc, val_acc, fold, save_folder):
    plt.figure(); plt.plot(train_losses,label='Train Loss'); plt.plot(val_losses,label='Val Loss')
    plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.title(f'Fold {fold} Loss'); plt.legend(); plt.grid(True)
    plt.savefig(os.path.join(save_folder,f'loss_fold{fold}.png')); plt.close()
    plt.figure(); plt.plot(train_acc,label='Train Acc'); plt.plot(val_acc,label='Val Acc')
    plt.xlabel('Epoch'); plt.ylabel('Accuracy (%)'); plt.title(f'Fold {fold} Accuracy'); plt.legend(); plt.grid(True)
    plt.savefig(os.path.join(save_folder,f'acc_fold{fold}.png')); plt.close()

# ====================== 划分训练集和测试集 ======================
X_proc = preprocess_iq_dataset_led_rff(X)
y_torch = torch.tensor(y, dtype=torch.long)

X_train_val, X_test, y_train_val, y_test = train_test_split(
    X_proc, y_torch, test_size=0.2, stratify=y_torch, random_state=42
)

# ====================== KFold 训练 ======================
def train_kfold(X_train, y_train, X_test, y_test, num_classes, device=DEVICE):
    timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
    save_dir = f"{timestamp}_LED_WiFi_SNR{SNR_dB}dB_fd{int(compute_doppler_shift(VELOCITY_KMH, FC))}_classes_{num_classes}_CNN"
    save_folder = os.path.join(SAVE_ROOT, save_dir)
    os.makedirs(save_folder, exist_ok=True)
    results_file = os.path.join(save_folder, "results.txt")
    
    # 保存实验参数
    with open(results_file, 'w') as f:
        f.write(f"Timestamp: {timestamp}\nNum Classes: {num_classes}\nSNR_dB: {SNR_dB}\nVELOCITY_KMH: {VELOCITY_KMH}\nFC: {FC}\nFS: {FS}\nWavelet: {WAVELET}, Level: {WAVELET_LEVEL}\nBatch: {BATCH_SIZE}, Epochs: {EPOCHS}, LR: {LR}, WD: {WEIGHT_DECAY}\n\n")
    
    test_dataset = TensorDataset(X_test, y_test)
    test_loader = DataLoader(test_dataset, batch_size=BATCH_SIZE, shuffle=False)
    
    full_dataset = TensorDataset(X_train, y_train)
    kf = KFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
    indices = np.arange(len(full_dataset))
    
    val_scores, test_scores = [], []
    
    for fold, (tr_idx, va_idx) in enumerate(kf.split(indices)):
        print(f"\n=== Fold {fold+1}/{N_SPLITS} ===")
        tr_sub, va_sub = Subset(full_dataset, tr_idx), Subset(full_dataset, va_idx)
        tr_loader = DataLoader(tr_sub, batch_size=BATCH_SIZE, shuffle=True)
        va_loader = DataLoader(va_sub, batch_size=BATCH_SIZE, shuffle=False)
        
        model = InceptionTime(num_classes=num_classes, in_channels=1, channels=16).to(device)
        criterion = nn.CrossEntropyLoss()
        optimizer = optim.Adam(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)
        scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)
        
        best_val, best_wts, patience_cnt = 0.0, None, 0
        train_losses, val_losses, train_acc_list, val_acc_list = [], [], [], []
        
        for epoch in range(EPOCHS):
            model.train(); running_loss, correct, total = 0.0, 0, 0
            for xb, yb in tr_loader:
                xb, yb = xb.to(device), yb.to(device)
                optimizer.zero_grad()
                out = model(xb)
                loss = criterion(out, yb)
                loss.backward()
                optimizer.step()
                running_loss += loss.item()
                _, p = torch.max(out,1)
                correct += (p==yb).sum().item()
                total += yb.size(0)
            train_loss = running_loss / len(tr_loader)
            train_acc = 100.0 * correct / total
            train_losses.append(train_loss)
            train_acc_list.append(train_acc)
            
            # Validation
            model.eval(); vloss, vcorrect, vtotal = 0.0,0,0
            with torch.no_grad():
                for xb, yb in va_loader:
                    xb, yb = xb.to(device), yb.to(device)
                    out = model(xb)
                    loss = criterion(out, yb)
                    vloss += loss.item()
                    _, p = torch.max(out,1)
                    vcorrect += (p==yb).sum().item()
                    vtotal += yb.size(0)
            val_loss = vloss / len(va_loader)
            val_acc = 100.0 * vcorrect / vtotal
            val_losses.append(val_loss)
            val_acc_list.append(val_acc)
            
            print(f"Epoch {epoch+1}/{EPOCHS} | TrainAcc={train_acc:.2f}% | ValAcc={val_acc:.2f}% | TrainLoss={train_loss:.4f} | ValLoss={val_loss:.4f}")
            with open(results_file, 'a') as f:
                f.write(f"Fold{fold+1} Epoch{epoch+1} | TrainAcc={train_acc:.2f}% | ValAcc={val_acc:.2f}% | TrainLoss={train_loss:.4f} | ValLoss={val_loss:.4f}\n")
            
            if val_acc > best_val + 0.1:
                best_val = val_acc
                best_wts = model.state_dict()
                patience_cnt = 0
            else:
                patience_cnt += 1
                if patience_cnt >= PATIENCE:
                    print("Early stopping.")
                    break
            scheduler.step()
        
        if best_wts is not None:
            model.load_state_dict(best_wts)
        
        # 测试集评估
        test_acc, test_cm = evaluate_model(model, test_loader, device, num_classes)
        print(f"Fold {fold+1} Test Accuracy: {test_acc:.2f}%")
        with open(results_file, 'a') as f:
            f.write(f"Fold {fold+1} TestAcc={test_acc:.2f}%\n")
        
        plot_confusion_matrix(test_cm, classes=list(range(num_classes)), fold=fold+1, save_folder=save_folder)
        plot_curves(train_losses, val_losses, train_acc_list, val_acc_list, fold+1, save_folder)
        torch.save(model.state_dict(), os.path.join(save_folder, f'model_fold{fold+1}.pth'))
        
        val_scores.append(val_acc)
        test_scores.append(test_acc)
        
    # 总结
    print("\n=== Overall Summary ===")
    print(f"Val Acc: {np.mean(val_scores):.2f} ± {np.std(val_scores):.2f}")
    print(f"Test Acc: {np.mean(test_scores):.2f} ± {np.std(test_scores):.2f}")
    with open(results_file, 'a') as f:
        f.write(f"\n=== Overall Summary ===\nVal Acc: {np.mean(val_scores):.2f} ± {np.std(val_scores):.2f}\nTest Acc: {np.mean(test_scores):.2f} ± {np.std(test_scores):.2f}\n")
    
    
    print(f"\nAll results saved in {save_folder}")
    return save_folder

# ====================== 执行训练 ======================
save_folder = train_kfold(X_train_val, y_train_val, X_test, y_test, num_classes=num_classes)
# Out:
# 第0个文件 (dev0.mat) 的数据 shape (转置后): (7014, 320)
# 第1个文件 (dev1.mat) 的数据 shape (转置后): (6632, 320)
# 第2个文件 (dev10.mat) 的数据 shape (转置后): (8935, 320)
# 第3个文件 (dev11.mat) 的数据 shape (转置后): (7776, 320)
# 第4个文件 (dev13.mat) 的数据 shape (转置后): (7410, 320)
# 第5个文件 (dev14.mat) 的数据 shape (转置后): (6274, 320)
# 第6个文件 (dev15.mat) 的数据 shape (转置后): (5706, 320)
# 第7个文件 (dev16.mat) 的数据 shape (转置后): (12968, 320)
# 第8个文件 (dev17.mat) 的数据 shape (转置后): (9508, 320)
# 第9个文件 (dev18.mat) 的数据 shape (转置后): (3343, 320)
# 第10个文件 (dev19.mat) 的数据 shape (转置后): (4756, 320)
# 第11个文件 (dev2.mat) 的数据 shape (转置后): (6316, 320)
# 第12个文件 (dev20.mat) 的数据 shape (转置后): (5592, 320)
# 第13个文件 (dev3.mat) 的数据 shape (转置后): (5536, 320)
# 第14个文件 (dev4.mat) 的数据 shape (转置后): (6669, 320)
# 第15个文件 (dev5.mat) 的数据 shape (转置后): (5237, 320)
# 第16个文件 (dev6.mat) 的数据 shape (转置后): (5460, 320)
# 第17个文件 (dev7.mat) 的数据 shape (转置后): (8926, 320)
# 第18个文件 (dev8.mat) 的数据 shape (转置后): (7614, 320)
# 第19个文件 (dev9.mat) 的数据 shape (转置后): (7232, 320)
# 总数据 shape: (138904, 320), 标签 shape: (138904,), 类别数: 20
#
# === Fold 1/5 ===
# Epoch 1/200 | TrainAcc=58.17% | ValAcc=28.13% | TrainLoss=1.2008 | ValLoss=3.2125
# Epoch 2/200 | TrainAcc=72.16% | ValAcc=32.78% | TrainLoss=0.7282 | ValLoss=2.4672
# Epoch 3/200 | TrainAcc=75.65% | ValAcc=21.89% | TrainLoss=0.6379 | ValLoss=3.4616
# Epoch 4/200 | TrainAcc=77.72% | ValAcc=13.15% | TrainLoss=0.5867 | ValLoss=6.8046
# Epoch 5/200 | TrainAcc=78.98% | ValAcc=58.88% | TrainLoss=0.5537 | ValLoss=1.3072
# Epoch 6/200 | TrainAcc=79.96% | ValAcc=48.33% | TrainLoss=0.5304 | ValLoss=1.8048
# Epoch 7/200 | TrainAcc=80.47% | ValAcc=61.84% | TrainLoss=0.5154 | ValLoss=1.0741
# Epoch 8/200 | TrainAcc=80.97% | ValAcc=74.68% | TrainLoss=0.5013 | ValLoss=0.6859
# Epoch 9/200 | TrainAcc=81.33% | ValAcc=55.50% | TrainLoss=0.4891 | ValLoss=1.9047
# Epoch 10/200 | TrainAcc=81.79% | ValAcc=45.21% | TrainLoss=0.4816 | ValLoss=2.1049
# Epoch 11/200 | TrainAcc=83.18% | ValAcc=62.06% | TrainLoss=0.4480 | ValLoss=1.2800
# Epoch 12/200 | TrainAcc=83.63% | ValAcc=81.36% | TrainLoss=0.4352 | ValLoss=0.4925
# Epoch 13/200 | TrainAcc=83.79% | ValAcc=78.41% | TrainLoss=0.4355 | ValLoss=0.6086
# Epoch 14/200 | TrainAcc=83.96% | ValAcc=70.03% | TrainLoss=0.4265 | ValLoss=0.8385
# Epoch 15/200 | TrainAcc=83.82% | ValAcc=80.37% | TrainLoss=0.4241 | ValLoss=0.5314
# Epoch 16/200 | TrainAcc=84.27% | ValAcc=79.66% | TrainLoss=0.4217 | ValLoss=0.5522
# Epoch 17/200 | TrainAcc=84.29% | ValAcc=82.89% | TrainLoss=0.4181 | ValLoss=0.4629
# Epoch 18/200 | TrainAcc=84.31% | ValAcc=71.55% | TrainLoss=0.4154 | ValLoss=0.7871
# Epoch 19/200 | TrainAcc=84.45% | ValAcc=62.50% | TrainLoss=0.4112 | ValLoss=1.3350
# Epoch 20/200 | TrainAcc=84.55% | ValAcc=75.15% | TrainLoss=0.4092 | ValLoss=0.6738
# Epoch 21/200 | TrainAcc=85.21% | ValAcc=83.36% | TrainLoss=0.3909 | ValLoss=0.4345
# Epoch 22/200 | TrainAcc=85.55% | ValAcc=83.46% | TrainLoss=0.3847 | ValLoss=0.4477
# Epoch 23/200 | TrainAcc=85.76% | ValAcc=83.17% | TrainLoss=0.3840 | ValLoss=0.4555
# Epoch 24/200 | TrainAcc=85.61% | ValAcc=81.80% | TrainLoss=0.3847 | ValLoss=0.4851
# Epoch 25/200 | TrainAcc=85.70% | ValAcc=82.28% | TrainLoss=0.3815 | ValLoss=0.4626
# Epoch 26/200 | TrainAcc=85.83% | ValAcc=79.83% | TrainLoss=0.3769 | ValLoss=0.5277
# Epoch 27/200 | TrainAcc=85.85% | ValAcc=82.86% | TrainLoss=0.3786 | ValLoss=0.4518
# Epoch 28/200 | TrainAcc=85.90% | ValAcc=81.15% | TrainLoss=0.3766 | ValLoss=0.4983
# Epoch 29/200 | TrainAcc=85.93% | ValAcc=81.07% | TrainLoss=0.3758 | ValLoss=0.5091
# Epoch 30/200 | TrainAcc=85.95% | ValAcc=78.91% | TrainLoss=0.3767 | ValLoss=0.5905
# Epoch 31/200 | TrainAcc=86.28% | ValAcc=80.17% | TrainLoss=0.3671 | ValLoss=0.5497
# Epoch 32/200 | TrainAcc=86.43% | ValAcc=83.73% | TrainLoss=0.3647 | ValLoss=0.4247
# Epoch 33/200 | TrainAcc=86.50% | ValAcc=84.04% | TrainLoss=0.3639 | ValLoss=0.4197
# Epoch 34/200 | TrainAcc=86.68% | ValAcc=82.38% | TrainLoss=0.3607 | ValLoss=0.4744
# Epoch 35/200 | TrainAcc=86.47% | ValAcc=83.35% | TrainLoss=0.3631 | ValLoss=0.4571
# Epoch 36/200 | TrainAcc=86.64% | ValAcc=84.80% | TrainLoss=0.3594 | ValLoss=0.4023
# Epoch 37/200 | TrainAcc=86.64% | ValAcc=83.35% | TrainLoss=0.3575 | ValLoss=0.4448
# Epoch 38/200 | TrainAcc=86.72% | ValAcc=83.78% | TrainLoss=0.3572 | ValLoss=0.4243
# Epoch 39/200 | TrainAcc=86.57% | ValAcc=84.26% | TrainLoss=0.3587 | ValLoss=0.4214
# Epoch 40/200 | TrainAcc=86.64% | ValAcc=83.50% | TrainLoss=0.3587 | ValLoss=0.4374
# Epoch 41/200 | TrainAcc=86.98% | ValAcc=84.80% | TrainLoss=0.3516 | ValLoss=0.4039
# Epoch 42/200 | TrainAcc=86.93% | ValAcc=83.91% | TrainLoss=0.3497 | ValLoss=0.4244
# Epoch 43/200 | TrainAcc=86.83% | ValAcc=84.86% | TrainLoss=0.3512 | ValLoss=0.3996
# Epoch 44/200 | TrainAcc=86.96% | ValAcc=84.85% | TrainLoss=0.3497 | ValLoss=0.4022
# Epoch 45/200 | TrainAcc=86.95% | ValAcc=84.76% | TrainLoss=0.3520 | ValLoss=0.4007
# Epoch 46/200 | TrainAcc=87.00% | ValAcc=84.49% | TrainLoss=0.3491 | ValLoss=0.4062
# Early stopping.
# Fold 1 Test Accuracy: 85.25%
#
# === Fold 2/5 ===
# Epoch 1/200 | TrainAcc=57.38% | ValAcc=34.67% | TrainLoss=1.2168 | ValLoss=1.9387
# Epoch 2/200 | TrainAcc=73.23% | ValAcc=67.32% | TrainLoss=0.7020 | ValLoss=0.8334
# Epoch 3/200 | TrainAcc=76.57% | ValAcc=45.61% | TrainLoss=0.6191 | ValLoss=1.9341
# Epoch 4/200 | TrainAcc=78.23% | ValAcc=55.15% | TrainLoss=0.5771 | ValLoss=1.1989
# Epoch 5/200 | TrainAcc=79.36% | ValAcc=55.30% | TrainLoss=0.5426 | ValLoss=1.2734
# Epoch 6/200 | TrainAcc=80.42% | ValAcc=51.18% | TrainLoss=0.5181 | ValLoss=1.7147
# Epoch 7/200 | TrainAcc=81.10% | ValAcc=56.63% | TrainLoss=0.5006 | ValLoss=1.5394
# Epoch 8/200 | TrainAcc=81.64% | ValAcc=62.80% | TrainLoss=0.4918 | ValLoss=1.0371
# Epoch 9/200 | TrainAcc=82.10% | ValAcc=64.58% | TrainLoss=0.4781 | ValLoss=1.1038
# Epoch 10/200 | TrainAcc=82.47% | ValAcc=53.84% | TrainLoss=0.4695 | ValLoss=1.6139
# Epoch 11/200 | TrainAcc=83.72% | ValAcc=80.08% | TrainLoss=0.4319 | ValLoss=0.5274
# Epoch 12/200 | TrainAcc=84.07% | ValAcc=80.30% | TrainLoss=0.4218 | ValLoss=0.5195
# Epoch 13/200 | TrainAcc=84.31% | ValAcc=79.68% | TrainLoss=0.4198 | ValLoss=0.5217
# Epoch 14/200 | TrainAcc=84.43% | ValAcc=78.56% | TrainLoss=0.4168 | ValLoss=0.5832
# Epoch 15/200 | TrainAcc=84.66% | ValAcc=81.94% | TrainLoss=0.4105 | ValLoss=0.4973
# Epoch 16/200 | TrainAcc=84.79% | ValAcc=80.27% | TrainLoss=0.4078 | ValLoss=0.5301
# Epoch 17/200 | TrainAcc=84.95% | ValAcc=63.19% | TrainLoss=0.4062 | ValLoss=1.1959
# Epoch 18/200 | TrainAcc=85.01% | ValAcc=82.06% | TrainLoss=0.4032 | ValLoss=0.4760
# Epoch 19/200 | TrainAcc=85.00% | ValAcc=82.70% | TrainLoss=0.4020 | ValLoss=0.4608
# Epoch 20/200 | TrainAcc=85.07% | ValAcc=80.87% | TrainLoss=0.3967 | ValLoss=0.5246
# Epoch 21/200 | TrainAcc=85.81% | ValAcc=84.14% | TrainLoss=0.3794 | ValLoss=0.4264
# Epoch 22/200 | TrainAcc=85.93% | ValAcc=77.65% | TrainLoss=0.3769 | ValLoss=0.6166
# Epoch 23/200 | TrainAcc=86.20% | ValAcc=84.59% | TrainLoss=0.3741 | ValLoss=0.4066
# Epoch 24/200 | TrainAcc=86.13% | ValAcc=84.33% | TrainLoss=0.3733 | ValLoss=0.4158
# Epoch 25/200 | TrainAcc=86.27% | ValAcc=83.98% | TrainLoss=0.3665 | ValLoss=0.4277
# Epoch 26/200 | TrainAcc=86.22% | ValAcc=84.18% | TrainLoss=0.3725 | ValLoss=0.4191
# Epoch 27/200 | TrainAcc=86.35% | ValAcc=83.96% | TrainLoss=0.3675 | ValLoss=0.4280
# Epoch 28/200 | TrainAcc=86.25% | ValAcc=83.84% | TrainLoss=0.3674 | ValLoss=0.4275
# Epoch 29/200 | TrainAcc=86.52% | ValAcc=81.77% | TrainLoss=0.3655 | ValLoss=0.4919
# Epoch 30/200 | TrainAcc=86.50% | ValAcc=82.62% | TrainLoss=0.3643 | ValLoss=0.4643
# Epoch 31/200 | TrainAcc=86.76% | ValAcc=83.42% | TrainLoss=0.3529 | ValLoss=0.4398
# Epoch 32/200 | TrainAcc=86.94% | ValAcc=84.91% | TrainLoss=0.3518 | ValLoss=0.4032
# Epoch 33/200 | TrainAcc=86.86% | ValAcc=84.67% | TrainLoss=0.3498 | ValLoss=0.4099
# Epoch 34/200 | TrainAcc=86.96% | ValAcc=83.58% | TrainLoss=0.3529 | ValLoss=0.4353
# Epoch 35/200 | TrainAcc=87.02% | ValAcc=84.35% | TrainLoss=0.3500 | ValLoss=0.4161
# Epoch 36/200 | TrainAcc=87.05% | ValAcc=83.78% | TrainLoss=0.3502 | ValLoss=0.4348
# Epoch 37/200 | TrainAcc=87.09% | ValAcc=85.15% | TrainLoss=0.3510 | ValLoss=0.3971
# Epoch 38/200 | TrainAcc=87.14% | ValAcc=84.25% | TrainLoss=0.3478 | ValLoss=0.4247
# Epoch 39/200 | TrainAcc=87.09% | ValAcc=85.66% | TrainLoss=0.3478 | ValLoss=0.3810
# Epoch 40/200 | TrainAcc=87.11% | ValAcc=85.67% | TrainLoss=0.3459 | ValLoss=0.3844
# Epoch 41/200 | TrainAcc=87.37% | ValAcc=85.54% | TrainLoss=0.3417 | ValLoss=0.3848
# Epoch 42/200 | TrainAcc=87.35% | ValAcc=85.77% | TrainLoss=0.3414 | ValLoss=0.3794
# Epoch 43/200 | TrainAcc=87.35% | ValAcc=85.56% | TrainLoss=0.3415 | ValLoss=0.3839
# Epoch 44/200 | TrainAcc=87.47% | ValAcc=85.63% | TrainLoss=0.3381 | ValLoss=0.3833
# Epoch 45/200 | TrainAcc=87.41% | ValAcc=84.62% | TrainLoss=0.3384 | ValLoss=0.4138
# Epoch 46/200 | TrainAcc=87.50% | ValAcc=85.69% | TrainLoss=0.3375 | ValLoss=0.3801
# Epoch 47/200 | TrainAcc=87.49% | ValAcc=85.72% | TrainLoss=0.3375 | ValLoss=0.3812
# Epoch 48/200 | TrainAcc=87.52% | ValAcc=85.85% | TrainLoss=0.3373 | ValLoss=0.3787
# Epoch 49/200 | TrainAcc=87.49% | ValAcc=85.73% | TrainLoss=0.3399 | ValLoss=0.3806
# Epoch 50/200 | TrainAcc=87.49% | ValAcc=85.48% | TrainLoss=0.3376 | ValLoss=0.3854
# Epoch 51/200 | TrainAcc=87.61% | ValAcc=85.77% | TrainLoss=0.3372 | ValLoss=0.3783
# Epoch 52/200 | TrainAcc=87.71% | ValAcc=85.15% | TrainLoss=0.3348 | ValLoss=0.3956
# Early stopping.
# Fold 2 Test Accuracy: 85.40%
#
# === Fold 3/5 ===
# Epoch 1/200 | TrainAcc=58.17% | ValAcc=8.64% | TrainLoss=1.2076 | ValLoss=7.8283
# Epoch 2/200 | TrainAcc=73.31% | ValAcc=40.07% | TrainLoss=0.7047 | ValLoss=1.8692
# Epoch 3/200 | TrainAcc=76.64% | ValAcc=45.77% | TrainLoss=0.6123 | ValLoss=2.4500
# Epoch 4/200 | TrainAcc=78.68% | ValAcc=27.37% | TrainLoss=0.5637 | ValLoss=6.0681
# Epoch 5/200 | TrainAcc=79.92% | ValAcc=78.13% | TrainLoss=0.5326 | ValLoss=0.5736
# Epoch 6/200 | TrainAcc=80.73% | ValAcc=26.70% | TrainLoss=0.5087 | ValLoss=4.6178
# Epoch 7/200 | TrainAcc=81.38% | ValAcc=24.73% | TrainLoss=0.4937 | ValLoss=4.2190
# Epoch 8/200 | TrainAcc=81.72% | ValAcc=62.78% | TrainLoss=0.4814 | ValLoss=1.1605
# Epoch 9/200 | TrainAcc=82.24% | ValAcc=78.18% | TrainLoss=0.4680 | ValLoss=0.5616
# Epoch 10/200 | TrainAcc=82.52% | ValAcc=60.40% | TrainLoss=0.4581 | ValLoss=1.3404
# Epoch 11/200 | TrainAcc=84.07% | ValAcc=76.88% | TrainLoss=0.4228 | ValLoss=0.6224
# Epoch 12/200 | TrainAcc=84.18% | ValAcc=81.53% | TrainLoss=0.4176 | ValLoss=0.5006
# Epoch 13/200 | TrainAcc=84.45% | ValAcc=80.14% | TrainLoss=0.4132 | ValLoss=0.5248
# Epoch 14/200 | TrainAcc=84.53% | ValAcc=43.73% | TrainLoss=0.4100 | ValLoss=2.3613
# Epoch 15/200 | TrainAcc=84.67% | ValAcc=67.40% | TrainLoss=0.4057 | ValLoss=0.9772
# Epoch 16/200 | TrainAcc=84.95% | ValAcc=80.95% | TrainLoss=0.4023 | ValLoss=0.5071
# Epoch 17/200 | TrainAcc=84.93% | ValAcc=69.09% | TrainLoss=0.3988 | ValLoss=0.9320
# Epoch 18/200 | TrainAcc=85.05% | ValAcc=63.91% | TrainLoss=0.3964 | ValLoss=1.1316
# Epoch 19/200 | TrainAcc=85.07% | ValAcc=64.44% | TrainLoss=0.3962 | ValLoss=1.0944
# Epoch 20/200 | TrainAcc=85.12% | ValAcc=74.62% | TrainLoss=0.3959 | ValLoss=0.7120
# Epoch 21/200 | TrainAcc=85.98% | ValAcc=83.24% | TrainLoss=0.3720 | ValLoss=0.4322
# Epoch 22/200 | TrainAcc=86.06% | ValAcc=81.37% | TrainLoss=0.3747 | ValLoss=0.5039
# Epoch 23/200 | TrainAcc=86.22% | ValAcc=75.81% | TrainLoss=0.3686 | ValLoss=0.6689
# Epoch 24/200 | TrainAcc=86.23% | ValAcc=76.99% | TrainLoss=0.3686 | ValLoss=0.6498
# Epoch 25/200 | TrainAcc=86.22% | ValAcc=83.69% | TrainLoss=0.3666 | ValLoss=0.4291
# Epoch 26/200 | TrainAcc=86.31% | ValAcc=78.66% | TrainLoss=0.3656 | ValLoss=0.6022
# Epoch 27/200 | TrainAcc=86.40% | ValAcc=81.96% | TrainLoss=0.3649 | ValLoss=0.4857
# Epoch 28/200 | TrainAcc=86.44% | ValAcc=82.11% | TrainLoss=0.3611 | ValLoss=0.4698
# Epoch 29/200 | TrainAcc=86.52% | ValAcc=83.10% | TrainLoss=0.3606 | ValLoss=0.4335
# Epoch 30/200 | TrainAcc=86.53% | ValAcc=76.76% | TrainLoss=0.3592 | ValLoss=0.6515
# Epoch 31/200 | TrainAcc=86.89% | ValAcc=84.05% | TrainLoss=0.3484 | ValLoss=0.4191
# Epoch 32/200 | TrainAcc=87.16% | ValAcc=83.98% | TrainLoss=0.3463 | ValLoss=0.4239
# Epoch 33/200 | TrainAcc=86.91% | ValAcc=85.17% | TrainLoss=0.3469 | ValLoss=0.3894
# Epoch 34/200 | TrainAcc=87.14% | ValAcc=84.97% | TrainLoss=0.3433 | ValLoss=0.3956
# Epoch 35/200 | TrainAcc=87.14% | ValAcc=83.55% | TrainLoss=0.3463 | ValLoss=0.4389
# Epoch 36/200 | TrainAcc=87.12% | ValAcc=84.79% | TrainLoss=0.3446 | ValLoss=0.3949
# Epoch 37/200 | TrainAcc=87.20% | ValAcc=84.61% | TrainLoss=0.3421 | ValLoss=0.4011
# Epoch 38/200 | TrainAcc=87.19% | ValAcc=85.58% | TrainLoss=0.3439 | ValLoss=0.3795
# Epoch 39/200 | TrainAcc=87.21% | ValAcc=83.59% | TrainLoss=0.3423 | ValLoss=0.4391
# Epoch 40/200 | TrainAcc=87.19% | ValAcc=81.46% | TrainLoss=0.3411 | ValLoss=0.5029
# Epoch 41/200 | TrainAcc=87.46% | ValAcc=85.24% | TrainLoss=0.3360 | ValLoss=0.3867
# Epoch 42/200 | TrainAcc=87.51% | ValAcc=85.24% | TrainLoss=0.3355 | ValLoss=0.3863
# Epoch 43/200 | TrainAcc=87.47% | ValAcc=84.22% | TrainLoss=0.3346 | ValLoss=0.4124
# Epoch 44/200 | TrainAcc=87.37% | ValAcc=85.42% | TrainLoss=0.3372 | ValLoss=0.3808
# Epoch 45/200 | TrainAcc=87.57% | ValAcc=84.32% | TrainLoss=0.3345 | ValLoss=0.4250
# Epoch 46/200 | TrainAcc=87.56% | ValAcc=85.11% | TrainLoss=0.3350 | ValLoss=0.3888
# Epoch 47/200 | TrainAcc=87.58% | ValAcc=85.12% | TrainLoss=0.3340 | ValLoss=0.3887
# Epoch 48/200 | TrainAcc=87.62% | ValAcc=84.67% | TrainLoss=0.3334 | ValLoss=0.4009
# Early stopping.
# Fold 3 Test Accuracy: 85.25%
#
# === Fold 4/5 ===
# Epoch 1/200 | TrainAcc=56.01% | ValAcc=32.56% | TrainLoss=1.2596 | ValLoss=2.7191
# Epoch 2/200 | TrainAcc=71.53% | ValAcc=37.70% | TrainLoss=0.7422 | ValLoss=2.8671
# Epoch 3/200 | TrainAcc=75.20% | ValAcc=32.05% | TrainLoss=0.6447 | ValLoss=2.6804
# Epoch 4/200 | TrainAcc=77.10% | ValAcc=72.22% | TrainLoss=0.5961 | ValLoss=0.7488
# Epoch 5/200 | TrainAcc=78.68% | ValAcc=51.28% | TrainLoss=0.5606 | ValLoss=1.7685
# Epoch 6/200 | TrainAcc=79.62% | ValAcc=59.98% | TrainLoss=0.5371 | ValLoss=1.3392
# Epoch 7/200 | TrainAcc=80.14% | ValAcc=35.21% | TrainLoss=0.5192 | ValLoss=2.6890
# Epoch 8/200 | TrainAcc=81.10% | ValAcc=63.25% | TrainLoss=0.4985 | ValLoss=1.0798
# Epoch 9/200 | TrainAcc=81.60% | ValAcc=68.12% | TrainLoss=0.4847 | ValLoss=0.9447
# Epoch 10/200 | TrainAcc=82.01% | ValAcc=43.76% | TrainLoss=0.4760 | ValLoss=3.5223
# Epoch 11/200 | TrainAcc=83.34% | ValAcc=81.34% | TrainLoss=0.4408 | ValLoss=0.4939
# Epoch 12/200 | TrainAcc=83.63% | ValAcc=78.89% | TrainLoss=0.4325 | ValLoss=0.5677
# Epoch 13/200 | TrainAcc=83.89% | ValAcc=75.07% | TrainLoss=0.4268 | ValLoss=0.6897
# Epoch 14/200 | TrainAcc=84.10% | ValAcc=76.67% | TrainLoss=0.4212 | ValLoss=0.6572
# Epoch 15/200 | TrainAcc=84.23% | ValAcc=60.73% | TrainLoss=0.4184 | ValLoss=1.1965
# Epoch 16/200 | TrainAcc=84.28% | ValAcc=78.70% | TrainLoss=0.4145 | ValLoss=0.5836
# Epoch 17/200 | TrainAcc=84.51% | ValAcc=72.94% | TrainLoss=0.4125 | ValLoss=0.7506
# Epoch 18/200 | TrainAcc=84.56% | ValAcc=82.56% | TrainLoss=0.4061 | ValLoss=0.4575
# Epoch 19/200 | TrainAcc=84.86% | ValAcc=79.42% | TrainLoss=0.4058 | ValLoss=0.5667
# Epoch 20/200 | TrainAcc=84.84% | ValAcc=75.54% | TrainLoss=0.4027 | ValLoss=0.6563
# Epoch 21/200 | TrainAcc=85.60% | ValAcc=82.52% | TrainLoss=0.3832 | ValLoss=0.4589
# Epoch 22/200 | TrainAcc=85.69% | ValAcc=79.99% | TrainLoss=0.3779 | ValLoss=0.5375
# Epoch 23/200 | TrainAcc=85.92% | ValAcc=82.99% | TrainLoss=0.3753 | ValLoss=0.4489
# Epoch 24/200 | TrainAcc=86.00% | ValAcc=82.27% | TrainLoss=0.3752 | ValLoss=0.4748
# Epoch 25/200 | TrainAcc=86.00% | ValAcc=82.86% | TrainLoss=0.3743 | ValLoss=0.4676
# Epoch 26/200 | TrainAcc=86.07% | ValAcc=83.30% | TrainLoss=0.3718 | ValLoss=0.4461
# Epoch 27/200 | TrainAcc=86.11% | ValAcc=82.04% | TrainLoss=0.3703 | ValLoss=0.4877
# Epoch 28/200 | TrainAcc=86.24% | ValAcc=80.90% | TrainLoss=0.3697 | ValLoss=0.5164
# Epoch 29/200 | TrainAcc=86.18% | ValAcc=80.77% | TrainLoss=0.3682 | ValLoss=0.5109
# Epoch 30/200 | TrainAcc=86.37% | ValAcc=84.00% | TrainLoss=0.3658 | ValLoss=0.4234
# Epoch 31/200 | TrainAcc=86.67% | ValAcc=84.71% | TrainLoss=0.3585 | ValLoss=0.4131
# Epoch 32/200 | TrainAcc=86.87% | ValAcc=84.37% | TrainLoss=0.3526 | ValLoss=0.4106
# Epoch 33/200 | TrainAcc=86.90% | ValAcc=85.17% | TrainLoss=0.3517 | ValLoss=0.3898
# Epoch 34/200 | TrainAcc=86.87% | ValAcc=83.68% | TrainLoss=0.3530 | ValLoss=0.4310
# Epoch 35/200 | TrainAcc=86.89% | ValAcc=83.00% | TrainLoss=0.3516 | ValLoss=0.4520
# Epoch 36/200 | TrainAcc=86.99% | ValAcc=84.84% | TrainLoss=0.3515 | ValLoss=0.4020
# Epoch 37/200 | TrainAcc=86.93% | ValAcc=84.47% | TrainLoss=0.3511 | ValLoss=0.4181
# Epoch 38/200 | TrainAcc=86.94% | ValAcc=84.03% | TrainLoss=0.3503 | ValLoss=0.4197
# Epoch 39/200 | TrainAcc=87.04% | ValAcc=85.02% | TrainLoss=0.3485 | ValLoss=0.3969
# Epoch 40/200 | TrainAcc=87.00% | ValAcc=84.22% | TrainLoss=0.3489 | ValLoss=0.4299
# Epoch 41/200 | TrainAcc=87.32% | ValAcc=85.18% | TrainLoss=0.3420 | ValLoss=0.3911
# Epoch 42/200 | TrainAcc=87.36% | ValAcc=85.26% | TrainLoss=0.3423 | ValLoss=0.3885
# Epoch 43/200 | TrainAcc=87.46% | ValAcc=85.41% | TrainLoss=0.3410 | ValLoss=0.3840
# Epoch 44/200 | TrainAcc=87.36% | ValAcc=85.55% | TrainLoss=0.3409 | ValLoss=0.3828
# Epoch 45/200 | TrainAcc=87.45% | ValAcc=85.70% | TrainLoss=0.3417 | ValLoss=0.3781
# Epoch 46/200 | TrainAcc=87.33% | ValAcc=85.38% | TrainLoss=0.3401 | ValLoss=0.3821
# Epoch 47/200 | TrainAcc=87.39% | ValAcc=85.46% | TrainLoss=0.3433 | ValLoss=0.3802
# Epoch 48/200 | TrainAcc=87.32% | ValAcc=85.50% | TrainLoss=0.3403 | ValLoss=0.3824
# Epoch 49/200 | TrainAcc=87.44% | ValAcc=85.61% | TrainLoss=0.3402 | ValLoss=0.3820
# Epoch 50/200 | TrainAcc=87.40% | ValAcc=85.70% | TrainLoss=0.3391 | ValLoss=0.3779
# Epoch 51/200 | TrainAcc=87.58% | ValAcc=85.02% | TrainLoss=0.3366 | ValLoss=0.3905
# Epoch 52/200 | TrainAcc=87.60% | ValAcc=85.63% | TrainLoss=0.3339 | ValLoss=0.3791
# Epoch 53/200 | TrainAcc=87.67% | ValAcc=85.66% | TrainLoss=0.3358 | ValLoss=0.3817
# Epoch 54/200 | TrainAcc=87.54% | ValAcc=85.66% | TrainLoss=0.3346 | ValLoss=0.3793
# Epoch 55/200 | TrainAcc=87.55% | ValAcc=85.64% | TrainLoss=0.3350 | ValLoss=0.3772
# Early stopping.
# Fold 4 Test Accuracy: 86.24%
#
# === Fold 5/5 ===
# Epoch 1/200 | TrainAcc=57.53% | ValAcc=51.10% | TrainLoss=1.2285 | ValLoss=1.2571
# Epoch 2/200 | TrainAcc=73.27% | ValAcc=61.41% | TrainLoss=0.7110 | ValLoss=0.9882
# Epoch 3/200 | TrainAcc=76.85% | ValAcc=71.88% | TrainLoss=0.6134 | ValLoss=0.7384
# Epoch 4/200 | TrainAcc=78.96% | ValAcc=56.18% | TrainLoss=0.5611 | ValLoss=1.3025
# Epoch 5/200 | TrainAcc=79.97% | ValAcc=77.16% | TrainLoss=0.5255 | ValLoss=0.6066
# Epoch 6/200 | TrainAcc=81.00% | ValAcc=63.78% | TrainLoss=0.5037 | ValLoss=1.0225
# Epoch 7/200 | TrainAcc=81.59% | ValAcc=65.06% | TrainLoss=0.4827 | ValLoss=1.0430
# Epoch 8/200 | TrainAcc=82.13% | ValAcc=68.71% | TrainLoss=0.4706 | ValLoss=0.8766
# Epoch 9/200 | TrainAcc=82.44% | ValAcc=33.59% | TrainLoss=0.4649 | ValLoss=4.8773
# Epoch 10/200 | TrainAcc=82.89% | ValAcc=70.72% | TrainLoss=0.4540 | ValLoss=0.8381
# Epoch 11/200 | TrainAcc=84.04% | ValAcc=77.30% | TrainLoss=0.4257 | ValLoss=0.6148
# Epoch 12/200 | TrainAcc=84.46% | ValAcc=59.96% | TrainLoss=0.4139 | ValLoss=1.3356
# Epoch 13/200 | TrainAcc=84.65% | ValAcc=77.60% | TrainLoss=0.4079 | ValLoss=0.6456
# Epoch 14/200 | TrainAcc=84.72% | ValAcc=79.45% | TrainLoss=0.4059 | ValLoss=0.5569
# Epoch 15/200 | TrainAcc=84.94% | ValAcc=83.84% | TrainLoss=0.3993 | ValLoss=0.4348
# Epoch 16/200 | TrainAcc=84.95% | ValAcc=72.66% | TrainLoss=0.3979 | ValLoss=0.7773
# Epoch 17/200 | TrainAcc=85.18% | ValAcc=82.32% | TrainLoss=0.3952 | ValLoss=0.4486
# Epoch 18/200 | TrainAcc=85.27% | ValAcc=78.06% | TrainLoss=0.3911 | ValLoss=0.5873
# Epoch 19/200 | TrainAcc=85.38% | ValAcc=78.33% | TrainLoss=0.3900 | ValLoss=0.6018
# Epoch 20/200 | TrainAcc=85.41% | ValAcc=83.82% | TrainLoss=0.3891 | ValLoss=0.4345
# Epoch 21/200 | TrainAcc=86.14% | ValAcc=82.40% | TrainLoss=0.3682 | ValLoss=0.4680
# Epoch 22/200 | TrainAcc=86.35% | ValAcc=81.60% | TrainLoss=0.3664 | ValLoss=0.4834
# Epoch 23/200 | TrainAcc=86.43% | ValAcc=85.02% | TrainLoss=0.3651 | ValLoss=0.3902
# Epoch 24/200 | TrainAcc=86.42% | ValAcc=76.39% | TrainLoss=0.3632 | ValLoss=0.6485
# Epoch 25/200 | TrainAcc=86.48% | ValAcc=74.92% | TrainLoss=0.3604 | ValLoss=0.6767
# Epoch 26/200 | TrainAcc=86.54% | ValAcc=84.92% | TrainLoss=0.3608 | ValLoss=0.4039
# Epoch 27/200 | TrainAcc=86.57% | ValAcc=82.82% | TrainLoss=0.3581 | ValLoss=0.4513
# Epoch 28/200 | TrainAcc=86.61% | ValAcc=81.17% | TrainLoss=0.3565 | ValLoss=0.5106
# Epoch 29/200 | TrainAcc=86.66% | ValAcc=84.58% | TrainLoss=0.3559 | ValLoss=0.4096
# Epoch 30/200 | TrainAcc=86.80% | ValAcc=78.77% | TrainLoss=0.3543 | ValLoss=0.5623
# Epoch 31/200 | TrainAcc=87.22% | ValAcc=85.13% | TrainLoss=0.3454 | ValLoss=0.3946
# Epoch 32/200 | TrainAcc=87.16% | ValAcc=85.56% | TrainLoss=0.3452 | ValLoss=0.3809
# Epoch 33/200 | TrainAcc=87.25% | ValAcc=85.79% | TrainLoss=0.3457 | ValLoss=0.3759
# Epoch 34/200 | TrainAcc=87.22% | ValAcc=84.73% | TrainLoss=0.3421 | ValLoss=0.3995
# Epoch 35/200 | TrainAcc=87.26% | ValAcc=85.83% | TrainLoss=0.3417 | ValLoss=0.3741
# Epoch 36/200 | TrainAcc=87.21% | ValAcc=85.20% | TrainLoss=0.3420 | ValLoss=0.3935
# Epoch 37/200 | TrainAcc=87.32% | ValAcc=85.75% | TrainLoss=0.3416 | ValLoss=0.3753
# Epoch 38/200 | TrainAcc=87.35% | ValAcc=85.70% | TrainLoss=0.3431 | ValLoss=0.3732
# Epoch 39/200 | TrainAcc=87.29% | ValAcc=86.11% | TrainLoss=0.3405 | ValLoss=0.3716
# Epoch 40/200 | TrainAcc=87.29% | ValAcc=84.25% | TrainLoss=0.3397 | ValLoss=0.4146
# Epoch 41/200 | TrainAcc=87.60% | ValAcc=86.08% | TrainLoss=0.3341 | ValLoss=0.3699
# Epoch 42/200 | TrainAcc=87.66% | ValAcc=86.51% | TrainLoss=0.3333 | ValLoss=0.3630
# Epoch 43/200 | TrainAcc=87.60% | ValAcc=85.94% | TrainLoss=0.3327 | ValLoss=0.3724
# Epoch 44/200 | TrainAcc=87.76% | ValAcc=86.64% | TrainLoss=0.3328 | ValLoss=0.3572
# Epoch 45/200 | TrainAcc=87.69% | ValAcc=86.18% | TrainLoss=0.3339 | ValLoss=0.3642
# Epoch 46/200 | TrainAcc=87.80% | ValAcc=86.37% | TrainLoss=0.3309 | ValLoss=0.3626
# Epoch 47/200 | TrainAcc=87.75% | ValAcc=86.33% | TrainLoss=0.3335 | ValLoss=0.3631
# Epoch 48/200 | TrainAcc=87.73% | ValAcc=86.18% | TrainLoss=0.3322 | ValLoss=0.3656
# Epoch 49/200 | TrainAcc=87.67% | ValAcc=85.95% | TrainLoss=0.3305 | ValLoss=0.3711
# Epoch 50/200 | TrainAcc=87.72% | ValAcc=86.17% | TrainLoss=0.3301 | ValLoss=0.3689
# Epoch 51/200 | TrainAcc=87.90% | ValAcc=86.24% | TrainLoss=0.3262 | ValLoss=0.3687
# Epoch 52/200 | TrainAcc=87.85% | ValAcc=86.58% | TrainLoss=0.3272 | ValLoss=0.3600
# Epoch 53/200 | TrainAcc=87.90% | ValAcc=86.57% | TrainLoss=0.3267 | ValLoss=0.3582
# Epoch 54/200 | TrainAcc=87.98% | ValAcc=86.32% | TrainLoss=0.3249 | ValLoss=0.3611
# Early stopping.
# Fold 5 Test Accuracy: 86.51%
#
# === Overall Summary ===
# Val Acc: 85.25 ± 0.67
# Test Acc: 85.73 ± 0.54
#
# All results saved in ./training_results\2025-11-24_15-04-10_LED_WiFi_SNR20dB_fd266_classes_20_CNN
