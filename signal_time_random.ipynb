# %%
import os
from scipy.io import loadmat

folder_path = r"..\los_data"  # 你的文件夹路径
file_list = [f for f in os.listdir(folder_path) if f.endswith('.mat')]  # 找到所有mat文件
file_list = sorted(file_list)  # 按文件名排序，比如 dev0.mat, dev1.mat, dev2.mat

data = []  # 用来存储每个mat文件中的 'data_Ineed'（转置后的）

for i, file_name in enumerate(file_list):
    full_path = os.path.join(folder_path, file_name)
    mat_contents = loadmat(full_path)
    if 'data_Ineed' in mat_contents:
        data_ineed = mat_contents['data_Ineed'].T  # 加上 .T 转置！
        data.append(data_ineed)
    else:
        print(f"Warning: {file_name} 里没有 'data_Ineed' 变量！")

# 打印检查
for i, d in enumerate(data):
    print(f"第{i}个文件（{file_list[i]}）的数据 shape (转置后): {d.shape},信号数量*采样点数量")
# Out:
# 第0个文件（dev0.mat）的数据 shape (转置后): (7014, 320),信号数量*采样点数量
# 第1个文件（dev1.mat）的数据 shape (转置后): (6632, 320),信号数量*采样点数量
# 第2个文件（dev10.mat）的数据 shape (转置后): (8935, 320),信号数量*采样点数量
# 第3个文件（dev11.mat）的数据 shape (转置后): (7776, 320),信号数量*采样点数量
# 第4个文件（dev13.mat）的数据 shape (转置后): (7410, 320),信号数量*采样点数量
# 第5个文件（dev14.mat）的数据 shape (转置后): (6274, 320),信号数量*采样点数量
# 第6个文件（dev15.mat）的数据 shape (转置后): (5706, 320),信号数量*采样点数量
# 第7个文件（dev16.mat）的数据 shape (转置后): (12968, 320),信号数量*采样点数量
# 第8个文件（dev17.mat）的数据 shape (转置后): (9508, 320),信号数量*采样点数量
# 第9个文件（dev18.mat）的数据 shape (转置后): (3343, 320),信号数量*采样点数量
# 第10个文件（dev19.mat）的数据 shape (转置后): (4756, 320),信号数量*采样点数量
# 第11个文件（dev2.mat）的数据 shape (转置后): (6316, 320),信号数量*采样点数量
# 第12个文件（dev20.mat）的数据 shape (转置后): (5592, 320),信号数量*采样点数量
# 第13个文件（dev3.mat）的数据 shape (转置后): (5536, 320),信号数量*采样点数量
# 第14个文件（dev4.mat）的数据 shape (转置后): (6669, 320),信号数量*采样点数量
# 第15个文件（dev5.mat）的数据 shape (转置后): (5237, 320),信号数量*采样点数量
# 第16个文件（dev6.mat）的数据 shape (转置后): (5460, 320),信号数量*采样点数量
# 第17个文件（dev7.mat）的数据 shape (转置后): (8926, 320),信号数量*采样点数量
# 第18个文件（dev8.mat）的数据 shape (转置后): (7614, 320),信号数量*采样点数量
# 第19个文件（dev9.mat）的数据 shape (转置后): (7232, 320),信号数量*采样点数量

# %%
import numpy as np

# 假设data是从之前的加载代码中获取的
# data = <从前一部分代码中加载的数据>

SNR_dB = -5  # 设定信噪比（dB）

noisy_data = []  # 用来存储加噪声后的数据

for d in data:
    # 计算信号的标准差
    signal_std = np.std(d)
    
    # 计算噪声的标准差，根据信噪比（SNR）
    noise_std = signal_std / (10 ** (SNR_dB / 20))  # 根据 SNR(dB) 计算噪声标准差
    
    # 生成高斯噪声并加到原信号上
    noise = np.random.normal(0, noise_std, d.shape)  # 均值为0，标准差为噪声标准差
    noisy_signal = d + noise  # 添加噪声
    
    noisy_data.append(noisy_signal)  # 保存加噪声后的信号

# 打印检查加噪声后的数据
print("原始数据和加噪声数据示例：")
print(f"原始信号样本（第一个信号）：{data[0][0][:10]}")  # 打印前10个采样点
print(f"加噪声信号样本（第一个信号）：{noisy_data[0][0][:10]}")  # 打印前10个采样点
# Out:
# 原始数据和加噪声数据示例：
# 原始信号样本（第一个信号）：[-0.01318091-0.00598181j -0.01379628-0.00492906j -0.017992  +0.00138218j
#  -0.185444  +0.24452379j -0.6173177 +0.97452922j -0.15240179+0.98618152j
#   0.87295696-0.30563645j  0.19726927-0.65624198j  0.0687799 +0.41792528j
#   0.95404651+0.17878775j]
# 加噪声信号样本（第一个信号）：[ 3.74881214-0.00598181j  2.06829455-0.00492906j  0.25251821+0.00138218j
#  -1.07041813+0.24452379j  0.12427222+0.97452922j -1.62815961+0.98618152j
#  -0.87517828-0.30563645j -2.01626637-0.65624198j  0.94204299+0.41792528j
#   3.74811586+0.17878775j]

# %%
import numpy as np

def compute_doppler_shift(v, fc):
    """
    根据移动速度 v (m/s) 和载波频率 fc (Hz) 计算多普勒频移
    """
    c = 3e8  # 光速 m/s
    return (v / c) * fc

def add_doppler_shift(signal, fd, fs):
    """
    给IQ信号加多普勒频移
    signal: shape (num_channels, num_samples)，复数IQ信号
    fd: 多普勒频移 (Hz)
    fs: 采样率 (Hz)
    """
    num_channels, num_samples = signal.shape
    t = np.arange(num_samples) / fs  # 时间轴
    doppler_phase = np.exp(1j * 2 * np.pi * fd * t)  # 复指数
    return signal * doppler_phase

# 例子
fs = 20e6  # 采样率，比如1 MHz
fc = 2.4e9  # 载波频率，比如2.4 GHz Wi-Fi
v = 120  # 移动速度，比如30 m/s (~108 km/h)

fd = compute_doppler_shift(v, fc)  # 先计算多普勒频移
print(f"计算得到的多普勒频移 fd = {fd:.2f} Hz")

# 假设 data 是你之前读出来的list，每个是 shape (信号数量, 采样点数)
data_with_doppler = []
for sig in noisy_data:
    shifted_sig = add_doppler_shift(sig, fd, fs)
    data_with_doppler.append(shifted_sig)

print("添加多普勒频移后的信号：")
print(data_with_doppler)
# Out:
# 计算得到的多普勒频移 fd = 960.00 Hz
# 添加多普勒频移后的信号：
# [array([[ 3.74881214e+00-5.98180779e-03j,  2.06829594e+00-4.30527379e-03j,
#          2.52517326e-01+1.53449983e-03j, ...,
#          6.16731635e-01+6.75318288e-01j,  3.27355550e-01-7.04980969e-01j,
#         -3.92648820e+00-3.64734284e-01j],
#        [-1.01799322e-01-6.65819948e-03j,  4.36414274e+00-4.27605597e-03j,
#         -3.26687118e-03+1.52807518e-04j, ...,
#         -2.64102767e+00-3.57220641e-01j,  9.47558271e-01-1.18668016e+00j,
#         -3.14965105e+00-6.96952542e-01j],
#        [ 2.46781758e-01+3.14398823e-03j,  5.80010395e-02+1.51891490e-03j,
#          5.23593074e-01-2.31765039e-03j, ...,
#          1.14441777e+00+6.31893096e-01j,  1.72214619e+00+1.51174057e+00j,
#          2.88924855e+00+7.39552301e-01j],
#        ...,
#        [-1.09362723e+00+1.49593753e-03j,  1.25556622e+00+1.24025271e-03j,
#         -1.97488206e-01+2.43261231e-02j, ...,
#          1.92333070e+00+1.23435051e+00j,  4.86867564e-01+1.26972653e+00j,
#          1.69051407e+00+5.16242580e-01j],
#        [-1.67601708e+00-2.77106919e-03j, -1.42060212e+00-3.89373647e-03j,
#         -1.02414886e-01+5.08531543e-02j, ...,
#         -2.71105345e-01-3.59745098e-01j, -2.83950859e+00-1.07841911e+00j,
#          1.32495909e+00+7.90102046e-01j],
#        [ 4.31903654e+00-1.99484085e-03j, -3.84484152e-01-2.05409634e-03j,
#          2.60439984e+00+2.26929019e-03j, ...,
#         -3.03947831e+00+5.91237745e-01j, -5.76484984e-01+2.66682271e-01j,
#          2.08621356e+00+6.81861378e-01j]], shape=(7014, 320)), array([[ 3.12783247-1.68155786e-02j, -1.34835124-1.80874016e-02j,
#         -0.44998385-2.45812871e-02j, ...,  0.01223085+2.32776891e-01j,
#         -1.23916841+9.60222562e-01j,  2.17581464+5.70644372e-02j],
#        [-0.65530123-1.37979496e-02j, -1.97562638-1.47017462e-02j,
#          0.28855855-4.60043557e-02j, ..., -0.02226528-8.31784150e-01j,
#         -0.03092228-9.83955480e-01j, -0.11902302-1.24135971e+00j],
#        [ 1.34578035-1.11077528e-03j,  0.85789978-2.24815615e-05j,
#          3.1019098 +4.27496554e-02j, ...,  0.69616906+8.07066753e-01j,
#         -2.80373461+3.79350491e-01j, -2.99617775+9.63094079e-01j],
#        ...,
#        [-0.41738124+5.40354334e-03j,  2.12815514+7.93938712e-03j,
#         -0.88590603+2.15893154e-02j, ..., -2.06933517+4.30479534e-01j,
#         -0.15181804-2.12168341e-01j, -0.4753094 +7.98557989e-01j],
#        [ 0.43876969+9.16804797e-03j,  0.99068828+7.27614406e-03j,
#         -0.78360897+4.10955904e-02j, ...,  0.35585467+8.62001841e-01j,
#         -1.43885177+8.46467234e-01j,  0.02096017+1.16445763e+00j],
#        [ 3.27588598-6.60294798e-03j,  0.72349832-7.69149653e-03j,
#          1.00632242-8.15252190e-02j, ..., -3.46677376-6.62441695e-01j,
#          2.03246536+8.79344600e-02j, -4.39482974-1.68576223e+00j]],
#       shape=(6632, 320)), array([[-1.45578383-0.02866302j,  1.84288151-0.02980144j,
#         -2.16872393-0.04745777j, ...,  1.55406682-0.79360625j,
#          0.82419298-0.20011151j,  1.09731758-0.1475407j ],
#        [-2.80334347-0.01964287j, -2.14390778-0.01540985j,
#         -1.97693693+0.12096958j, ...,  2.41055816+0.22271253j,
#         -3.40608329-0.75837795j, -2.10422228+0.66038971j],
#        [-0.57152513-0.0211156j ,  0.52634311-0.0199319j ,
#          0.28754065+0.04761264j, ..., -1.67569799-0.08912518j,
#          0.23158905-0.64544694j, -2.11312163+0.36349464j],
#        ...,
#        [ 0.89634654+0.00498973j, -0.68569624+0.00763218j,
#          1.81954519+0.08177438j, ..., -3.07978173-0.62083664j,
#          0.92637848-0.7267146j ,  1.64357066+0.58572817j],
#        [-0.40179654-0.00540016j,  2.33043693-0.01167476j,
#          1.25386766-0.11711477j, ...,  0.29401301-0.82570338j,
#         -1.24695123-0.84195641j,  0.54568142-1.15240135j],
#        [ 1.00841621+0.00236253j, -1.00133664+0.00630987j,
#          0.85547772+0.05926311j, ...,  0.51411096+0.11855365j,
#          1.85218975-0.61382356j, -1.08067273+0.22683299j]],
#       shape=(8935, 320)), array([[ 0.59941058+6.04403166e-03j, -1.18450024+1.34355037e-02j,
#          0.05742457+1.84004337e-01j, ..., -1.09436126-3.72888793e-02j,
#         -3.23713284-4.50350132e-01j, -2.21865812+9.70571133e-01j],
#        [-1.46871803+1.62000500e-02j,  1.01624771+1.76498671e-02j,
#          1.83105872+3.25335542e-02j, ..., -2.87803911-3.24092159e-01j,
#          0.13880747-1.24396700e+00j, -4.36302616-9.05582253e-01j],
#        [ 1.31063978-1.23921413e-03j, -0.92209683-2.68820514e-03j,
#          1.84603203-8.77199835e-02j, ...,  1.41044446-8.05019778e-01j,
#          4.70381272-1.69456783e-02j, -0.95764216-1.25256025e+00j],
#        ...,
#        [-0.32503643-1.25821438e-02j, -1.36101809-2.13954319e-02j,
#          1.26172302-1.74907821e-01j, ..., -0.63477074+5.13299575e-01j,
#         -4.71792362+1.31163483e-01j,  1.87352571-7.02591633e-01j],
#        [-1.10433708+2.13484864e-03j, -1.61924036+3.47838515e-03j,
#         -0.66051371+8.98683110e-02j, ..., -0.88599852+8.97175588e-01j,
#         -0.30771028+5.36473658e-01j,  3.89361571+1.59231242e+00j],
#        [-1.82688103-1.39238324e-02j,  1.07444378-1.44680680e-02j,
#         -2.18951893-3.08026555e-02j, ...,  3.54410134+9.27302154e-01j,
#          1.32546781+1.46558634e+00j,  1.14279787+5.36265835e-01j]],
#       shape=(7776, 320)), array([[-2.20737736-5.58918821e-03j,  1.52677357-4.75935097e-03j,
#         -0.62930066-3.01959138e-03j, ...,  1.12735977+1.14134960e-01j,
#          3.16996755+1.57948415e+00j,  0.11650979+1.12240712e+00j],
#        [ 0.81690961-1.07341297e-02j,  0.06165382-1.11526511e-02j,
#          1.19599693-3.32120150e-02j, ..., -0.28206688-8.20987905e-01j,
#         -0.24205669-1.27365330e+00j,  0.25408244-9.53936294e-01j],
#        [ 1.30447596-9.14526096e-03j,  2.41433301-6.75403886e-03j,
#          1.02951982+1.58410087e-02j, ..., -1.48109056+4.72613616e-01j,
#          0.16569189-1.57093536e-01j, -1.94791715+5.71208687e-01j],
#        ...,
#        [-1.70825593+3.08435656e-03j,  0.40893591+3.69442279e-03j,
#          1.05028603+2.09844938e-03j, ..., -1.49694014-5.12089257e-01j,
#         -1.63212635+8.97495026e-01j,  2.63874675+7.00918803e-01j],
#        [-1.47941523+9.31707491e-05j,  0.0248492 +7.49453021e-04j,
#          3.5810821 -2.47492604e-04j, ..., -0.04593578-1.62183608e-01j,
#          0.59226383-1.10199793e+00j,  0.64776943-1.14387202e+00j],
#        [-1.32539057+2.11910878e-03j,  0.36454874+3.01576594e-03j,
#          2.1574534 +1.38670706e-03j, ...,  0.1591225 -6.11349985e-01j,
#         -0.15778567-8.49949740e-01j, -0.39437427-9.92185632e-01j]],
#       shape=(7410, 320)), array([[ 1.3522174 +0.17627416j,  1.27739908+0.821796j  ,
#         -0.15203414-0.09858957j, ..., -0.36586382-0.72741679j,
#          2.24371387-0.80976158j, -1.06833898-1.11365609j],
#        [ 1.93594185+0.34427072j,  1.37597213+0.82035405j,
#          0.90039436-0.37374431j, ...,  0.77471888-0.76459863j,
#          3.49053425+0.03281599j, -1.71969974-0.41080796j],
#        [ 1.72183289+0.15586186j, -0.37748678-0.44275744j,
#          0.43458688-0.50186136j, ...,  1.9418486 +0.17864762j,
#         -0.77350633+1.24601583j, -1.5764429 +1.28735187j],
#        ...,
#        [-0.74889937-0.11107594j, -1.01301619+0.54418185j,
#         -1.38321471+0.349967j  , ...,  1.77344283-0.13145281j,
#          2.04946998-1.20929553j, -1.14810512-0.79135761j],
#        [ 0.11391589-0.42538272j, -1.97713961-0.81528029j,
#          1.31143491+0.54725478j, ...,  1.75153371+0.97197224j,
#         -2.36676641+0.19744518j,  0.34380696+0.55946254j],
#        [ 2.34270808+0.20158519j, -2.82954108+0.85238526j,
#          1.07130974-0.03283057j, ...,  1.17490165-0.64104137j,
#         -0.69086466-0.78393071j,  1.15099151-0.43444683j]],
#       shape=(6274, 320)), array([[-3.09123486+0.17676383j, -0.22503102-0.32418173j,
#          0.24296957-0.66183332j, ..., -1.31088875+0.1172948j ,
#          0.18908415+1.18951302j,  0.8347795 +0.92980754j],
#        [-0.58301802+0.54702624j,  2.14577809+0.33570383j,
#          2.13848907-0.96534173j, ...,  1.26351923-0.45466261j,
#          2.67565164+0.58075925j,  3.42997034+0.20559309j],
#        [-2.60064732+0.07917728j,  4.65521134+0.73540613j,
#         -0.81117492+0.35147899j, ..., -0.91613764-0.47267163j,
#          0.52468453-1.09012888j,  2.32839933-0.84001591j],
#        ...,
#        [ 1.92831058-0.96306959j, -0.0104713 -0.19389512j,
#          0.83033412+1.14277232j, ..., -0.73185929+0.72615338j,
#          1.35085255+0.85167656j, -2.45790706+0.73009685j],
#        [ 0.15828381-0.79776804j,  2.21223003+0.16048076j,
#          1.37775984+1.28788774j, ..., -3.47262349-0.30261571j,
#         -1.15722665-0.45614898j, -3.14453102-0.04796141j],
#        [-2.1105402 +0.6097643j ,  0.39813959-0.24381276j,
#          1.67799057-1.17005817j, ..., -3.03081902-0.28292669j,
#          3.85669508+0.8590904j ,  2.53397631+0.12941305j]],
#       shape=(5706, 320)), array([[-0.40909089+0.06840523j,  1.67200295+0.64658587j,
#         -2.694671  +0.37493702j, ...,  1.30852289-0.13177507j,
#         -2.05732463-1.44838075j, -1.31696882-1.18874165j],
#        [-0.01244015+0.2747257j , -1.09762452-0.0866608j ,
#         -0.13939467-0.79610694j, ..., -0.5204667 -0.3660726j ,
#          2.72483267+1.26449835j, -0.09502747+1.02726479j],
#        [ 0.47925993+0.36397322j, -1.88383442+0.32842755j,
#          2.97638585-0.76428564j, ..., -0.65669955-0.64372475j,
#         -1.82597395+0.46823155j,  2.43890075+0.66562661j],
#        ...,
#        [ 1.72288833-0.50048191j, -1.64616055-0.54876678j,
#          1.09577188+0.80699886j, ..., -1.05481516+0.68881871j,
#         -0.3827147 -0.08806813j,  0.41548127+0.26583299j],
#        [ 0.4113088 -0.30832252j,  1.14550231+0.09132707j,
#          0.51163811+0.84204124j, ..., -1.48845092+0.14839075j,
#          1.29666945-0.86189364j, -0.67559164-0.60278252j],
#        [-1.64643557-0.48783719j, -0.08469605-0.8179463j ,
#          1.02535972+0.56336144j, ..., -0.47620104+0.84847946j,
#         -2.12864769+0.29893766j, -1.63098926+0.48246502j]],
#       shape=(12968, 320)), array([[ 1.67865238-0.19821906j,  3.8506949 +0.4206986j ,
#         -1.87956987+0.58929081j, ...,  0.56884679-0.22133703j,
#         -0.59771143-1.19703919j,  1.42764028-0.63381123j],
#        [-1.10258987-0.82174j   ,  1.68922439-0.53452635j,
#         -0.17032754+1.1120166j , ...,  2.46616608+0.89706628j,
#         -2.7025682 -0.2301791j , -3.04271719+0.25177613j],
#        [ 2.37496266-0.466624j  ,  2.78616998+0.1591077j ,
#         -3.48643427+0.9293718j , ..., -3.99325678-0.44178781j,
#         -2.93341968-1.32125382j, -0.70104135-0.37510334j],
#        ...,
#        [-2.02397393-0.13938279j,  3.36411363+0.4472348j ,
#         -1.54337483+0.5306788j , ..., -0.56575676-0.18034105j,
#         -1.80600201-1.48866173j, -1.13990177-0.93630142j],
#        [-0.13892913+0.46359171j,  1.03991927+0.93603039j,
#         -0.90270411-0.58521638j, ..., -1.48000472-1.00360995j,
#          0.91585302-0.16617738j, -0.79919711-0.45916789j],
#        [-0.09115057-0.43668965j,  0.88072169-0.37104722j,
#         -1.50843435+0.81476808j, ...,  1.61157894+0.73281351j,
#         -4.40961706-1.15868265j, -1.40408165-0.50426557j]],
#       shape=(9508, 320)), array([[-0.47487087+0.40289134j, -1.39592721+0.30966566j,
#         -0.27834524-0.66360884j, ..., -1.1412166 -1.17447514j,
#          0.03172728-1.09768561j,  1.26205392-1.02690241j],
#        [ 3.22214425+0.1174917j ,  3.09636001+0.44100367j,
#          0.40042978+0.18537073j, ..., -2.94477204-0.57061122j,
#          0.40970854-1.37710641j,  3.10166128-0.89102876j],
#        [-1.28832364-0.38004509j,  2.00608892+0.0670445j ,
#          4.36163659+1.01608505j, ...,  0.0572335 +0.67875563j,
#          0.40961789+0.12441301j, -2.01571233+0.86926085j],
#        ...,
#        [ 2.04863507+0.42532171j,  0.66730601+0.2912197j ,
#         -0.23438644-0.64319643j, ...,  1.73710398-0.92838325j,
#          3.39949674-0.89580072j, -1.56907124-1.22944833j],
#        [ 1.03009401-0.09738405j, -0.33980449-0.40785281j,
#         -0.19466859-0.26656076j, ...,  3.01156409+0.44383818j,
#         -1.21663756+1.25115586j,  0.45776341+1.30670876j],
#        [-2.25651034+0.14463491j,  2.72712463+0.39183799j,
#          0.74272693-0.47083875j, ..., -2.83703131-1.41240404j,
#          2.69368656+0.0282542j ,  2.14837486-0.12354101j]],
#       shape=(3343, 320)), array([[-0.7352283 +0.00000000e+00j,  2.38366953+7.18897815e-04j,
#          0.02543839+1.53440751e-05j, ...,  0.73329056+7.03205866e-02j,
#         -0.06623843-6.37224773e-03j,  2.98940255+2.88495494e-01j],
#        [ 3.10900217+0.00000000e+00j,  2.90951564+8.77489270e-04j,
#         -4.67618392-2.82060803e-03j, ...,  2.71083184+2.59961462e-01j,
#         -2.41994258-2.32802536e-01j, -0.79317393-7.65460994e-02j],
#        [ 1.02422984-1.16866697e-01j,  2.13973002-3.53695208e-01j,
#          2.98175054-1.59425550e-01j, ...,  1.50131985+3.69016961e-01j,
#          0.52684367+1.17713538e+00j, -0.61380847-3.88217391e-01j],
#        ...,
#        [-0.82851689-6.86455072e-02j,  1.6280198 -1.27949209e-02j,
#          0.4434507 +8.48305128e-01j, ..., -2.69351873+4.72334778e-01j,
#         -0.40436816+1.11505491e+00j, -0.83206803+9.38009961e-01j],
#        [-2.74218625-4.11200930e-02j, -0.1403839 -4.19342358e-02j,
#          3.22634066+4.16169949e-01j, ..., -0.42465578+3.46312441e-01j,
#         -1.2201025 +3.55769798e-01j, -0.83272293+8.70480172e-01j],
#        [-2.41070191+3.45535823e-02j,  1.39964906+1.12395696e-01j,
#         -1.06527202-1.78758346e-01j, ..., -1.01329669-2.40810191e-01j,
#          5.18028491-3.36247645e-01j, -2.40047051-1.40121453e+00j]],
#       shape=(4756, 320)), array([[-3.42252106-8.27848820e-03j, -1.8313176 -1.02335412e-02j,
#         -0.62620046+7.17365674e-02j, ..., -0.24078114-6.94563548e-02j,
#         -2.14477811-5.65551140e-01j,  0.41396723+1.09806168e+00j],
#        [ 0.79824877-7.27186684e-04j, -1.84475382+5.09239347e-04j,
#         -0.28175337-1.46398007e-02j, ..., -0.60403447+3.18983561e-01j,
#          1.25855832+1.26361114e+00j,  1.41987079-1.62659172e-01j],
#        [-2.10646998+3.47028408e-03j,  0.8442842 +1.97088485e-03j,
#          1.06507004-2.60928798e-02j, ...,  2.17496285+2.19084481e-01j,
#          0.11742573+8.42050436e-01j, -0.53524844-6.92044304e-01j],
#        ...,
#        [-0.68342061-5.01316521e-03j, -2.22806851-6.27399832e-03j,
#          2.19206433+1.16201431e-01j, ..., -2.86762947+8.11536693e-02j,
#         -1.82584443+1.74729630e-01j, -0.4539734 +1.20017704e+00j],
#        [-3.22788323-2.47533782e-03j,  1.9182643 -1.02579932e-03j,
#          0.9856847 -7.17517715e-05j, ..., -2.75859125+3.03731041e-01j,
#          0.51511081-9.26709518e-01j, -4.8391737 -1.48096947e+00j],
#        [-1.45901536-3.74025965e-03j, -0.74883899-2.58181004e-03j,
#          0.64216957+1.60651692e-02j, ...,  1.02381036+8.76924259e-01j,
#          0.25137758+1.01831159e+00j, -0.46630244+1.06132179e+00j]],
#       shape=(6316, 320)), array([[ 0.50513758-0.2938319j ,  3.25641144+0.15941735j,
#          4.27904629+0.79987722j, ..., -1.52457259+0.23296243j,
#         -0.32807054-1.06571987j,  1.82541501-1.1082948j ],
#        [-0.75661681+0.31766863j,  1.72853223+1.28974036j,
#         -3.01540012-0.25396262j, ..., -1.96553942-1.04270205j,
#          2.73044267-0.23494054j,  1.0355622 -0.3082024j ],
#        [ 1.56724527+0.22062231j, -5.00939541-0.39807982j,
#         -1.72023754-0.77755316j, ..., -1.79524154-0.48119029j,
#          1.7718376 +1.30685873j, -0.86285879+1.00254162j],
#        ...,
#        [-1.21879116+0.29590076j, -1.11837277+1.25722785j,
#         -1.85651947-0.03830866j, ..., -4.64144944-1.10307581j,
#          0.93301899-0.96852661j, -1.36908034-1.29879238j],
#        [-1.77656292-0.49164613j,  1.28101156-1.24873704j,
#         -1.18788545+0.54719188j, ..., -1.97062304+0.680013j  ,
#         -1.62486519+0.23150756j,  1.88938973+0.62920611j],
#        [-0.98655004+0.49089523j, -1.98840987+1.2271336j ,
#         -0.96929785-0.56076134j, ...,  0.31839165-0.8474716j ,
#         -1.7788974 -0.56452858j,  0.25796824-0.40240882j]],
#       shape=(5592, 320)), array([[-0.61694167-0.01689641j,  0.72503668-0.01828088j,
#          2.90974604-0.00970909j, ..., -3.26829621-0.79018319j,
#          0.94936604-1.16386838j, -1.90988627-0.19972492j],
#        [ 1.88043146-0.00449824j,  2.11227286-0.00269454j,
#         -0.78784113-0.00158521j, ...,  2.73424044+0.21241951j,
#          0.65139516+1.32733302j,  0.9793337 +1.16219781j],
#        [-1.77676365-0.00360087j, -0.93145122-0.00480866j,
#          0.11582639+0.03477762j, ...,  1.30933835+1.15977866j,
#          2.93973952+1.52022929j,  1.74017667+0.58882062j],
#        ...,
#        [ 0.71958794+0.01271144j,  3.37426635+0.01457098j,
#         -2.55316641+0.0106493j , ..., -1.86960434-1.10845474j,
#         -0.94057537-0.26863357j,  0.33475091-0.27268158j],
#        [-0.3225756 -0.0090405j , -2.32093872-0.0095059j ,
#          2.23040608-0.00574987j, ..., -0.75318185+0.65109486j,
#          0.18063287-0.77521538j, -3.38165037-0.64938073j],
#        [-0.79456358-0.00488898j, -1.28309604-0.00499191j,
#          0.97758299-0.00364034j, ...,  1.24214167+0.52538037j,
#         -0.40038072-1.18500878j, -3.41852794-1.28541365j]],
#       shape=(5536, 320)), array([[ 1.07385854-5.17339126e-03j, -2.10132645-4.28897335e-03j,
#          0.49481097+2.20579639e-03j, ..., -0.94768537+3.84092502e-01j,
#          0.18609349-8.61026338e-01j, -1.6751169 -3.37112156e-01j],
#        [-1.67150346-8.97961416e-04j,  2.9444454 -1.63846970e-03j,
#          2.93462181+3.78157327e-02j, ..., -3.17682104-7.89255119e-02j,
#         -5.08790345-9.79893249e-01j, -2.73582473+4.91131319e-01j],
#        [-0.72611266-2.01487227e-03j,  1.10002229-1.86804154e-03j,
#          0.38477935-1.23273113e-03j, ...,  0.86688641-3.50436533e-01j,
#         -2.25357566-1.57131230e+00j, -0.85814251-4.78145135e-01j],
#        ...,
#        [ 3.23752211+1.26645303e-02j, -0.54483537+1.05055567e-02j,
#          1.78371607+1.64558629e-02j, ..., -2.5278477 +1.74442692e-01j,
#          0.69528391-9.27256718e-01j, -2.47345529-5.97482545e-01j],
#        [-4.08372158+3.62666977e-03j, -2.16529241+3.06098488e-03j,
#         -3.70508436+1.68721576e-03j, ..., -0.53413928-2.14107827e-01j,
#          0.38161282-1.07329119e+00j,  2.16514835-1.01240423e+00j],
#        [-3.39180911+7.80560509e-04j, -1.13226571+5.42948167e-04j,
#         -2.54851573+1.25336011e-02j, ..., -0.17912463+7.70531414e-01j,
#          1.68648416+9.53660531e-01j, -3.84316074+7.29078021e-01j]],
#       shape=(6669, 320)), array([[ 0.67244957-0.04157866j, -1.80878543-0.04822737j,
#         -1.55482481-0.1353882j , ..., -1.29764671-0.92654537j,
#          1.59093439-0.85794144j, -1.59899147-1.16431181j],
#        [ 1.28745398-0.02562551j, -0.34995204-0.0276281j ,
#          2.49252753-0.00236963j, ..., -1.94518113-0.36073385j,
#          0.79623581-1.00396423j,  0.10009388-0.21888365j],
#        [ 0.41252762+0.02119722j,  2.15201268+0.02532072j,
#          5.0502637 +0.11389837j, ...,  0.18538563+0.77733365j,
#         -0.88745338+0.47063324j, -0.57972617+1.09559489j],
#        ...,
#        [ 1.56678117-0.03138001j,  4.25250552-0.02966523j,
#          0.27297699-0.04276932j, ..., -0.97906212-0.63355272j,
#          0.48240666-1.1465245j , -3.07546564-0.91959412j],
#        [ 0.91529853+0.61098652j,  2.43757499+0.38351639j,
#          0.37274324-0.52180596j, ...,  2.25002957-0.48227932j,
#         -0.41689136-0.25332527j,  2.16908556+0.70493321j],
#        [ 0.38552104+0.02764757j,  0.52550548+0.02964458j,
#         -2.00526928+0.03860247j, ...,  2.1110722 +1.02653135j,
#         -0.93917787+1.00636471j, -0.61840472+0.15277114j]],
#       shape=(5237, 320)), array([[-0.17775993-0.00781024j,  0.3279263 -0.00961713j,
#          3.25597055-0.04221085j, ...,  2.10842592-0.59847489j,
#          5.89338764+0.73979773j,  3.91768922-0.07434032j],
#        [ 1.57438398+0.00369563j, -0.18198244+0.01080346j,
#          1.34735465+0.13670382j, ..., -3.13003076+0.50969336j,
#         -0.54710066+0.55845024j,  0.57242532+1.31637703j],
#        [-5.30558809+0.01678896j,  2.27724042+0.01799197j,
#          0.38823733+0.05422325j, ...,  1.97920665+0.92289663j,
#          2.30319497+1.06989243j, -1.78622904+0.89683681j],
#        ...,
#        [-0.30045045-0.01380172j, -2.91599318-0.0160184j ,
#         -0.96697752-0.04430464j, ...,  1.22263646-0.68374614j,
#         -2.25634563-0.84202403j, -2.08525928-1.08867531j],
#        [-0.12770131+0.01035644j, -1.82225832+0.01121196j,
#         -1.34039341+0.01549662j, ..., -0.17109292-0.25535843j,
#          1.30248685+1.16786263j, -1.77310918+0.68234966j],
#        [-0.52297961+0.01312824j, -1.34105642+0.01377127j,
#          0.84289482+0.0218404j , ..., -0.6815726 -0.01300123j,
#          0.74642611+1.11417761j, -1.35267006+0.9362275j ]],
#       shape=(5460, 320)), array([[-1.60114847-1.60398363e-02j,  2.71168023-1.60726798e-02j,
#         -1.59411233-5.87652282e-02j, ...,  0.55385559-4.03032431e-01j,
#          0.97937876-1.13304813e+00j, -1.51494155-1.07261631e+00j],
#        [ 1.23315424+4.54155886e-03j, -0.41878693+5.35185748e-03j,
#          1.73891541+1.30015039e-02j, ...,  3.76636429+2.55858886e-01j,
#          0.32001627+1.33973593e+00j,  0.34094431+6.37319323e-01j],
#        [ 1.107115  +8.38097556e-03j, -2.29931899+9.03181901e-03j,
#         -0.68739644+1.49650807e-02j, ...,  1.19832218-3.77534320e-01j,
#         -2.32825414+7.82608534e-01j,  0.10395029+1.16941566e+00j],
#        ...,
#        [ 3.72571635+1.27326199e-02j, -1.4786475 +1.69939228e-02j,
#         -1.48682977+1.51325490e-01j, ..., -3.28379338+6.28781830e-01j,
#          3.74371779+1.46809158e+00j, -2.21025321+6.30091234e-01j],
#        [ 0.77868315-1.26691524e-03j, -0.0119988 -9.68311282e-03j,
#          1.13385576-1.44216187e-01j, ...,  2.28784227-3.71996204e-01j,
#          0.4920331 -4.70976549e-01j, -1.23339243-1.30637633e+00j],
#        [ 0.84546619-1.05043188e-02j,  0.46680428-7.52721079e-03j,
#          0.62171309-3.14553530e-02j, ...,  0.34668095-2.67330112e-01j,
#         -0.29891719-1.45738387e+00j, -1.78300001-9.86813478e-01j]],
#       shape=(8926, 320)), array([[-4.94434255-1.43382042e-02j, -0.3658433 -1.79300567e-02j,
#          3.44606251-5.45985088e-02j, ...,  2.44055796-5.71704405e-01j,
#          3.66319128-5.16117134e-01j, -0.46293941-1.15351150e+00j],
#        [ 2.33964635-1.06725591e-03j, -3.65092331-7.06923680e-04j,
#         -3.28302407+3.24990767e-04j, ...,  1.896414  +1.06173913e-01j,
#         -1.99212057+1.18151692e+00j,  1.84223447+1.05642478e+00j],
#        [-1.46873435+4.40387420e-03j, -0.43380308+5.89476746e-03j,
#          0.48365856+8.88209042e-02j, ..., -1.30578151+6.29471367e-01j,
#         -2.14816526+3.38332121e-01j, -1.96739488+9.04137940e-01j],
#        ...,
#        [-1.29607755-8.69412245e-03j,  0.44167639-1.26300246e-02j,
#         -1.11389825-1.32308562e-01j, ...,  2.95521711-4.82071092e-01j,
#         -0.10096323-5.86461381e-01j,  2.18860301-9.31773509e-01j],
#        [ 1.02755462+5.20007096e-03j, -2.17168248+9.18805052e-03j,
#         -1.50326509+6.28995124e-02j, ..., -3.03099163+5.24495018e-01j,
#         -0.59120628+1.12421235e+00j, -0.55081207+9.55520351e-01j],
#        [ 0.40526925+4.24815400e-03j, -0.6119503 +1.18962086e-02j,
#          2.21695834+1.24018570e-01j, ..., -0.3242785 +1.05679745e+00j,
#         -0.10277628+1.17561079e+00j,  0.25590346+8.18200006e-01j]],
#       shape=(7614, 320)), array([[ 0.09941502-0.00585862j, -1.69764029-0.00245328j,
#         -1.06791317+0.15044255j, ..., -0.78393574+0.07321868j,
#         -2.55372361-0.55230348j, -0.12629764+0.99402914j],
#        [-0.46145781-0.01431051j,  0.30678135-0.01995905j,
#         -4.32648405-0.16128638j, ..., -0.13780522-0.60108481j,
#          2.94852151+0.16126774j,  0.79239241-1.0899372j ],
#        [-0.45112498-0.01820837j,  2.49290054-0.02168047j,
#         -1.63943308-0.12189595j, ...,  0.78846754-0.11877646j,
#         -2.78585733+0.23229244j,  3.44551428-0.48904281j],
#        ...,
#        [-1.44850425-0.00880126j,  1.02587198-0.01303601j,
#         -4.22907611-0.10441711j, ...,  2.70100405-0.53331827j,
#          0.95593263-0.21027088j,  1.15933835-0.94043219j],
#        [ 1.18973381-0.00895245j, -3.52395501-0.0141149j ,
#          1.46039063-0.08693357j, ..., -0.27783467-0.90281691j,
#          2.85968093-0.33388492j, -1.18381885-1.2463671j ],
#        [ 1.18462846-0.00492866j, -2.60181908-0.00710974j,
#          3.27282429-0.03179j   , ..., -0.84195208-0.53572309j,
#          0.49312546-1.40046841j, -0.82266731-1.04527365j]],
#       shape=(7232, 320))]

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import random
from datetime import datetime
from tqdm import tqdm
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns
import matplotlib.pyplot as plt

# =================== 设备检查 ===================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# =================== 数据准备 ===================
# 假设 data_with_doppler 是你的列表，每个元素 shape = (样本数, 320)
all_data = []
all_labels = []

for device_idx, device_signals in enumerate(data_with_doppler):
    device_labels = np.full((device_signals.shape[0],), device_idx)
    all_data.append(torch.tensor(device_signals, dtype=torch.float32))
    all_labels.append(torch.tensor(device_labels, dtype=torch.long))

all_data = torch.cat(all_data, dim=0)
all_labels = torch.cat(all_labels, dim=0)

dataset = TensorDataset(all_data, all_labels)

# ------------------- 划分训练/验证/测试集 -------------------
test_ratio = 0.2
val_ratio = 0.2

test_size = int(len(dataset) * test_ratio)
train_val_size = len(dataset) - test_size

train_val_dataset, test_dataset = random_split(dataset, [train_val_size, test_size])

train_size = int(train_val_size * (1 - val_ratio))
val_size = train_val_size - train_size

train_dataset, val_dataset = random_split(train_val_dataset, [train_size, val_size])

# ==== 数据增强：对训练集添加高斯噪声 ====
def add_noise_to_dataset(dataset, noise_std=0.01):
    noisy_data = []
    noisy_labels = []
    for x, y in dataset:
        noise = torch.randn_like(x) * noise_std
        noisy_x = x + noise
        noisy_data.append(noisy_x)
        noisy_labels.append(y)
    noisy_data = torch.stack(noisy_data)
    noisy_labels = torch.tensor(noisy_labels)
    return TensorDataset(noisy_data, noisy_labels)

train_dataset = add_noise_to_dataset(train_dataset, noise_std=0.01)

# =================== Transformer 模型定义 ===================
class SignalTransformer(nn.Module):
    def __init__(self, input_dim, model_dim, num_heads, num_layers, num_classes, dropout=0.1):
        super(SignalTransformer, self).__init__()
        self.embedding = nn.Linear(input_dim, model_dim)
        self.transformer = nn.Transformer(
            d_model=model_dim,
            nhead=num_heads,
            num_encoder_layers=num_layers,
            dropout=dropout,
            batch_first=True
        )
        self.fc = nn.Linear(model_dim, num_classes)
    
    def forward(self, x):
        x = self.embedding(x)
        x = self.transformer(x, x)
        if len(x.shape) == 3:
            x = x[:, -1, :]
        x = self.fc(x)
        return x

# =================== 参数空间 ===================
param_space = {
    "model_dim": [64, 128, 256],     # 新增
    "num_heads": [2, 4, 8],
    "num_layers": [1, 2, 3],
    "dropout": [0.1, 0.3, 0.5],
    "learning_rate": [1e-3, 5e-4, 1e-4],
    "weight_decay": [1e-4, 1e-5],
    "batch_size": [64, 128, 256]
}

num_classes = 20
input_dim = 320
num_trials = 100
num_epoch = 300

timestamp = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
script_name = "time_random"
folder_name = f"{timestamp}_{script_name}_SNR{SNR_dB}dB_fd{fd}_classes_{num_classes}_Transformer"
save_folder = os.path.join(os.getcwd(), "search_results", folder_name)
os.makedirs(save_folder, exist_ok=True)
results_file = os.path.join(save_folder, "results.txt")

trial_results = []
best_result = {"val_acc": 0}

# =================== 训练+验证+测试流程 ===================
def train_and_evaluate(hparams):
    batch_size = hparams["batch_size"]
    lr = hparams["learning_rate"]
    wd = hparams["weight_decay"]

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    model = SignalTransformer(
        input_dim=input_dim,
        model_dim=hparams["model_dim"],  # 使用 model_dim
        num_heads=hparams["num_heads"],
        num_layers=hparams["num_layers"],
        num_classes=num_classes,
        dropout=hparams["dropout"]
    ).to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay=wd)
    patience, patience_counter = 8, 0
    best_val_loss = float("inf")

    for epoch in range(num_epoch):
        # ===== 训练阶段 =====
        model.train()
        train_correct, train_total = 0, 0
        for inputs, labels in train_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            _, preds = torch.max(outputs, 1)
            train_total += labels.size(0)
            train_correct += (preds == labels).sum().item()

        train_acc = 100 * train_correct / train_total

        # ===== 验证阶段 =====
        val_loss, val_correct, val_total = 0, 0, 0
        model.eval()
        with torch.no_grad():
            for inputs, labels in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, preds = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (preds == labels).sum().item()

        val_acc = 100 * val_correct / val_total

        # 早停检查
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            patience_counter = 0
            best_model_state = model.state_dict()
            best_train_acc = train_acc  # 记录当时的训练集准确率
        else:
            patience_counter += 1

        if patience_counter >= patience:
            break

    # ===== 测试阶段 =====
    model.load_state_dict(best_model_state)
    test_correct, test_total = 0, 0
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            test_total += labels.size(0)
            test_correct += (preds == labels).sum().item()

    test_acc = 100 * test_correct / test_total

    return {
        "train_acc": best_train_acc,   # 新增
        "val_loss": best_val_loss / len(val_loader),
        "val_acc": val_acc,
        "test_acc": test_acc,
        "best_model_state": best_model_state
    }

# =================== 随机搜索循环 ===================
for trial in range(num_trials):
    hparams = {k: random.choice(v) for k, v in param_space.items()}
    print(f"\n=== Trial {trial+1}/{num_trials} ===")
    print(hparams)

    metrics = train_and_evaluate(hparams)

    record = {**hparams,
              "train_acc": metrics["train_acc"],  # 新增
              "val_acc": metrics["val_acc"],
              "test_acc": metrics["test_acc"]}
    trial_results.append(record)

    print(f"Train Acc: {metrics['train_acc']:.2f}%, "
          f"Validation Acc: {metrics['val_acc']:.2f}%, "
          f"Test Acc: {metrics['test_acc']:.2f}%")

    with open(results_file, "a") as f:
        f.write(f"Trial {trial+1}: {record}\n")

    if metrics["val_acc"] > best_result.get("val_acc", 0):
        best_result = {**record}
        best_model_path = os.path.join(save_folder, "best_model_state.pth")
        torch.save(metrics["best_model_state"], best_model_path)


with open(results_file, "a") as f:
    f.write("\n=== Best Result ===\n")
    f.write(str(best_result) + "\n")

print("Random search finished.")
print("Best params:", best_result)

# =================== 混淆矩阵绘制 ===================
def plot_confusion_matrix(best_model_state, best_hparams):
    batch_size = best_hparams["batch_size"]
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    model = SignalTransformer(
        input_dim=input_dim,
        model_dim=best_hparams["model_dim"],    # 适配 model_dim
        num_heads=best_hparams["num_heads"],
        num_layers=best_hparams["num_layers"],
        num_classes=num_classes,
        dropout=best_hparams["dropout"]
    ).to(device)
    model.load_state_dict(best_model_state)
    model.eval()

    all_preds, all_labels = [], []
    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.append(preds.cpu())
            all_labels.append(labels.cpu())

    all_preds = torch.cat(all_preds).numpy()
    all_labels = torch.cat(all_labels).numpy()

    cm = confusion_matrix(all_labels, all_preds)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=np.arange(num_classes))
    plt.figure(figsize=(12, 10))
    disp.plot(cmap=plt.cm.Blues, values_format='d', ax=plt.gca())
    plt.title("Confusion Matrix - Best Model")
    cm_path = os.path.join(save_folder, "best_model_confusion_matrix.png")
    plt.savefig(cm_path, dpi=300)
    plt.close()
    print(f"Confusion matrix saved to: {cm_path}")

# 调用混淆矩阵绘制（注意这里传入保存的 best_model_state）
plot_confusion_matrix(torch.load(best_model_path), best_result)
# Out:
# Using device: cuda
#
# === Trial 1/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 21.66%, Validation Acc: 20.04%, Test Acc: 19.89%
#
# === Trial 2/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.07%, Validation Acc: 20.54%, Test Acc: 20.04%
#
# === Trial 3/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.34%, Validation Acc: 20.49%, Test Acc: 20.03%
#
# === Trial 4/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 5/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.18%, Validation Acc: 20.12%, Test Acc: 19.88%
#
# === Trial 6/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 24.03%, Validation Acc: 19.40%, Test Acc: 19.18%
#
# === Trial 7/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.41%, Validation Acc: 19.73%, Test Acc: 19.81%
#
# === Trial 8/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 19.41%, Validation Acc: 18.85%, Test Acc: 18.62%
#
# === Trial 9/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 21.92%, Validation Acc: 20.17%, Test Acc: 19.60%
#
# === Trial 10/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 22.72%, Validation Acc: 20.16%, Test Acc: 19.85%
#
# === Trial 11/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 22.73%, Validation Acc: 20.17%, Test Acc: 19.70%
#
# === Trial 12/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 18.25%, Validation Acc: 18.33%, Test Acc: 18.28%
#
# === Trial 13/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 22.32%, Validation Acc: 20.34%, Test Acc: 20.15%
#
# === Trial 14/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 19.30%, Validation Acc: 18.32%, Test Acc: 18.33%
#
# === Trial 15/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 16/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 22.99%, Validation Acc: 20.44%, Test Acc: 20.34%
#
# === Trial 17/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 15.44%, Validation Acc: 14.59%, Test Acc: 14.37%
#
# === Trial 18/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 19/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 22.73%, Validation Acc: 20.44%, Test Acc: 20.23%
#
# === Trial 20/100 ===
# {'model_dim': 64, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 22.65%, Validation Acc: 20.58%, Test Acc: 20.27%
#
# === Trial 21/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 23.42%, Validation Acc: 17.88%, Test Acc: 17.69%
#
# === Trial 22/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 23/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 23.11%, Validation Acc: 18.83%, Test Acc: 18.33%
#
# === Trial 24/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 17.98%, Validation Acc: 17.98%, Test Acc: 17.64%
#
# === Trial 25/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 22.79%, Validation Acc: 15.59%, Test Acc: 15.43%
#
# === Trial 26/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 20.73%, Validation Acc: 20.13%, Test Acc: 19.39%
#
# === Trial 27/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 28/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 9.31%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 29/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 18.56%, Validation Acc: 18.19%, Test Acc: 18.10%
#
# === Trial 30/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.04%, Validation Acc: 20.35%, Test Acc: 20.06%
#
# === Trial 31/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 23.79%, Validation Acc: 16.76%, Test Acc: 16.48%
#
# === Trial 32/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 33/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 34/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 16.91%, Validation Acc: 17.21%, Test Acc: 16.80%
#
# === Trial 35/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 22.02%, Validation Acc: 20.99%, Test Acc: 21.19%
#
# === Trial 36/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 23.31%, Validation Acc: 15.53%, Test Acc: 15.38%
#
# === Trial 37/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 22.23%, Validation Acc: 18.05%, Test Acc: 17.95%
#
# === Trial 38/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 23.84%, Validation Acc: 19.31%, Test Acc: 19.00%
#
# === Trial 39/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 40/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 41/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 20.87%, Validation Acc: 19.60%, Test Acc: 19.05%
#
# === Trial 42/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 43/100 ===
# {'model_dim': 64, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 21.09%, Validation Acc: 20.26%, Test Acc: 20.12%
#
# === Trial 44/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 23.10%, Validation Acc: 15.60%, Test Acc: 15.41%
#
# === Trial 45/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 22.67%, Validation Acc: 19.89%, Test Acc: 19.63%
#
# === Trial 46/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 19.90%, Validation Acc: 19.35%, Test Acc: 19.10%
#
# === Trial 47/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 48/100 ===
# {'model_dim': 64, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 23.26%, Validation Acc: 20.13%, Test Acc: 20.01%
#
# === Trial 49/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 22.44%, Validation Acc: 17.26%, Test Acc: 16.84%
#
# === Trial 50/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 22.72%, Validation Acc: 17.00%, Test Acc: 16.78%
#
# === Trial 51/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.29%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 52/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 22.62%, Validation Acc: 19.74%, Test Acc: 19.63%
#
# === Trial 53/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 23.28%, Validation Acc: 19.98%, Test Acc: 20.07%
#
# === Trial 54/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 55/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 56/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 23.36%, Validation Acc: 19.78%, Test Acc: 19.70%
#
# === Trial 57/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.25%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 58/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 18.96%, Validation Acc: 18.71%, Test Acc: 18.29%
#
# === Trial 59/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 21.38%, Validation Acc: 20.22%, Test Acc: 20.00%
#
# === Trial 60/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 23.85%, Validation Acc: 17.45%, Test Acc: 17.56%
#
# === Trial 61/100 ===
# {'model_dim': 64, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 21.23%, Validation Acc: 19.97%, Test Acc: 19.26%
#
# === Trial 62/100 ===
# {'model_dim': 64, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 23.21%, Validation Acc: 20.85%, Test Acc: 20.23%
#
# === Trial 63/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 23.15%, Validation Acc: 19.23%, Test Acc: 18.77%
#
# === Trial 64/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 65/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 20.99%, Validation Acc: 20.55%, Test Acc: 20.12%
#
# === Trial 66/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 22.43%, Validation Acc: 20.35%, Test Acc: 20.00%
#
# === Trial 67/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.14%, Validation Acc: 20.31%, Test Acc: 19.89%
#
# === Trial 68/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.50%, Validation Acc: 19.87%, Test Acc: 19.95%
#
# === Trial 69/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 70/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 71/100 ===
# {'model_dim': 256, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 20.59%, Validation Acc: 20.06%, Test Acc: 19.70%
#
# === Trial 72/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 21.64%, Validation Acc: 20.67%, Test Acc: 20.33%
#
# === Trial 73/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 22.06%, Validation Acc: 20.22%, Test Acc: 19.81%
#
# === Trial 74/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 21.55%, Validation Acc: 20.66%, Test Acc: 20.23%
#
# === Trial 75/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.83%, Validation Acc: 21.06%, Test Acc: 20.49%
#
# === Trial 76/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.04%, Validation Acc: 17.99%, Test Acc: 18.07%
#
# === Trial 77/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 78/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 9.17%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 79/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 80/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 23.53%, Validation Acc: 20.00%, Test Acc: 19.83%
#
# === Trial 81/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 21.48%, Validation Acc: 20.52%, Test Acc: 20.27%
#
# === Trial 82/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 83/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 22.60%, Validation Acc: 20.17%, Test Acc: 19.69%
#
# === Trial 84/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 22.36%, Validation Acc: 18.36%, Test Acc: 18.14%
#
# === Trial 85/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 18.51%, Validation Acc: 18.38%, Test Acc: 18.33%
#
# === Trial 86/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 23.53%, Validation Acc: 19.06%, Test Acc: 18.18%
#
# === Trial 87/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 88/100 ===
# {'model_dim': 256, 'num_heads': 8, 'num_layers': 2, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 128}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 89/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 90/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.1, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 23.38%, Validation Acc: 19.93%, Test Acc: 19.27%
#
# === Trial 91/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 20.84%, Validation Acc: 20.14%, Test Acc: 20.01%
#
# === Trial 92/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 21.80%, Validation Acc: 19.63%, Test Acc: 19.12%
#
# === Trial 93/100 ===
# {'model_dim': 256, 'num_heads': 2, 'num_layers': 2, 'dropout': 0.1, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 8.50%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 94/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 22.98%, Validation Acc: 20.61%, Test Acc: 20.34%
#
# === Trial 95/100 ===
# {'model_dim': 64, 'num_heads': 8, 'num_layers': 3, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 64}
# Train Acc: 9.30%, Validation Acc: 9.49%, Test Acc: 9.32%
#
# === Trial 96/100 ===
# {'model_dim': 64, 'num_heads': 2, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.001, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 20.95%, Validation Acc: 20.46%, Test Acc: 20.11%
#
# === Trial 97/100 ===
# {'model_dim': 64, 'num_heads': 4, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0005, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 17.81%, Validation Acc: 18.07%, Test Acc: 18.02%
#
# === Trial 98/100 ===
# {'model_dim': 128, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 256}
# Train Acc: 22.17%, Validation Acc: 20.44%, Test Acc: 19.72%
#
# === Trial 99/100 ===
# {'model_dim': 128, 'num_heads': 2, 'num_layers': 3, 'dropout': 0.3, 'learning_rate': 0.0005, 'weight_decay': 0.0001, 'batch_size': 128}
# Train Acc: 21.10%, Validation Acc: 20.35%, Test Acc: 20.22%
#
# === Trial 100/100 ===
# {'model_dim': 128, 'num_heads': 4, 'num_layers': 2, 'dropout': 0.5, 'learning_rate': 0.001, 'weight_decay': 1e-05, 'batch_size': 256}
# Train Acc: 9.29%, Validation Acc: 9.49%, Test Acc: 9.32%
# Random search finished.
# Best params: {'model_dim': 64, 'num_heads': 8, 'num_layers': 1, 'dropout': 0.5, 'learning_rate': 0.0001, 'weight_decay': 0.0001, 'batch_size': 128, 'train_acc': 22.82623378962536, 'val_acc': 21.061867266591676, 'test_acc': 20.48956083513319}
# Confusion matrix saved to: d:\Program\MW-RFF\MW-RFF\search_results\2025-08-15_17-54-04_time_random_SNR-5dB_fd960.0_classes_20_Transformer\best_model_confusion_matrix.png
